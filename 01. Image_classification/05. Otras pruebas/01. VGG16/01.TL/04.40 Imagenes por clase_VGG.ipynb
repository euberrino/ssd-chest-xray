# %% [markdown]
# #Montaje e Importación de Librerías

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/2020 - Quinto Anio/TESIS_Eugenia_Berrino
# Out:
# /content/drive/MyDrive/2020 - Quinto Anio/TESIS_Eugenia_Berrino

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Flatten, Dense, Dropout,GlobalAveragePooling2D
from tensorflow.keras import Sequential
from tensorflow.keras.layers.experimental.preprocessing import RandomRotation,RandomFlip,Rescaling, RandomContrast, RandomTranslation, RandomZoom
from tensorflow.keras.callbacks import EarlyStopping , ReduceLROnPlateau
import shutil
from tensorflow.keras.models import load_model, Model, Sequential
from sklearn.metrics import classification_report, confusion_matrix
import itertools
from matplotlib import pyplot as plt
from keras import applications

# %% [markdown]
# #El modelo
#
# https://towardsdatascience.com/understanding-and-coding-a-resnet-in-keras-446d7ff84d33
# https://github.com/priya-dwivedi/Deep-Learning/tree/master/resnet_keras

# %% [markdown]
# ## Definiciones, Importacion de imágenes

# %%
IMAGE_SIZE = (128,128)
NUM_CLASSES = 3 
BATCH_SIZE = 32

# %%
df_train=pd.read_excel("train_40imgs.xlsx")
df_test=pd.read_excel("test0-7.xlsx")

# %%
train_datagen = ImageDataGenerator(validation_split = 0.2)#,rescale = 1./255,horizontal_flip=True,rotation_range=40)
dir = '/content/drive/My Drive/2020 - Quinto Anio/TESIS_Eugenia_Berrino/DS_comp_nodef'
train_batches = train_datagen.flow_from_dataframe( #tomamos info de un df
    df_train, 
    directory=dir,
    x_col='ImageID',y_col='Projection',
    target_size=IMAGE_SIZE,
    shuffle=True,
    batch_size=BATCH_SIZE,
    subset = "training",
    seed=42,
    class_mode="categorical",)
# Out:
# Found 96 validated image filenames belonging to 3 classes.

# %%
valid_batches = train_datagen.flow_from_dataframe(df_train, directory=dir,
                                            x_col='ImageID',y_col='Projection',
                                            target_size=IMAGE_SIZE,
                                            shuffle=True,
                                            batch_size=BATCH_SIZE,
                                            subset = "validation",
                                            seed=42,
                                            class_mode="categorical",)
# Out:
# Found 24 validated image filenames belonging to 3 classes.

# %%
data_augmentation = Sequential([  #package: experimental.preprocessing
  Rescaling(1./255, input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)), #NN work better with small values
  RandomFlip('horizontal'),
  RandomRotation(0.2),
  RandomContrast(0.2),
  RandomTranslation(height_factor=0.2,width_factor=0.2),
  RandomZoom( height_factor = (-0.2,0.2),width_factor = (-0.2,0.2))
])

# %%
model = models.Sequential()
model.add(data_augmentation)
conv_base = VGG16(weights="imagenet", include_top=False,
                  input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))  
conv_base.trainable = False 
model.add(conv_base)
model.add(layers.Flatten()) 
model.add(layers.Dense(256, activation="relu")) 
model.add(layers.Dense(NUM_CLASSES, activation="softmax")) 
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 128, 128, 3)       0
# _________________________________________________________________
# vgg16 (Functional)           (None, 4, 4, 512)         14714688
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               2097408
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 771
# =================================================================
# Total params: 16,812,867
# Trainable params: 2,098,179
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
from keras.optimizers import SGD, Adam
# sgd = SGD(lr=lrate, momentum=0.9, decay=decay, nesterov=False)
adam = Adam(lr=0.05) #0.001
model.compile(optimizer= adam, loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ##Train

# %%
history = model.fit(train_batches, validation_data = valid_batches , epochs = 200,workers=10, callbacks=[EarlyStopping(monitor='val_loss',patience=40,restore_best_weights=True),ReduceLROnPlateau(monitor='val_loss',factor = 0.1,patience=5,min_lr=0)], batch_size = BATCH_SIZE)
# Out:
# Epoch 1/200
# 3/3 [==============================] - 32s 12s/step - loss: 64.3897 - accuracy: 0.4635 - val_loss: 144.8727 - val_accuracy: 0.4583
# Epoch 2/200
# 3/3 [==============================] - 1s 250ms/step - loss: 145.6473 - accuracy: 0.2865 - val_loss: 27.2818 - val_accuracy: 0.3333
# Epoch 3/200
# 3/3 [==============================] - 1s 296ms/step - loss: 26.2976 - accuracy: 0.3828 - val_loss: 6.5928 - val_accuracy: 0.3333
# Epoch 4/200
# 3/3 [==============================] - 1s 272ms/step - loss: 6.5991 - accuracy: 0.4974 - val_loss: 9.8315 - val_accuracy: 0.5417
# Epoch 5/200
# 3/3 [==============================] - 1s 263ms/step - loss: 7.8437 - accuracy: 0.5000 - val_loss: 0.6971 - val_accuracy: 0.7500
# Epoch 6/200
# 3/3 [==============================] - 1s 329ms/step - loss: 1.6350 - accuracy: 0.6289 - val_loss: 0.8150 - val_accuracy: 0.7083
# Epoch 7/200
# 3/3 [==============================] - 1s 321ms/step - loss: 1.5134 - accuracy: 0.6654 - val_loss: 2.3791 - val_accuracy: 0.4167
# Epoch 8/200
# 3/3 [==============================] - 1s 294ms/step - loss: 1.8495 - accuracy: 0.5820 - val_loss: 0.4765 - val_accuracy: 0.8333
# Epoch 9/200
# 3/3 [==============================] - 1s 287ms/step - loss: 0.5674 - accuracy: 0.8034 - val_loss: 0.4967 - val_accuracy: 0.9167
# Epoch 10/200
# 3/3 [==============================] - 1s 256ms/step - loss: 0.5352 - accuracy: 0.7812 - val_loss: 0.5848 - val_accuracy: 0.7917
# Epoch 11/200
# 3/3 [==============================] - 1s 249ms/step - loss: 0.5517 - accuracy: 0.7448 - val_loss: 0.4453 - val_accuracy: 0.7917
# Epoch 12/200
# 3/3 [==============================] - 1s 274ms/step - loss: 0.4982 - accuracy: 0.8594 - val_loss: 0.3973 - val_accuracy: 0.7917
# Epoch 13/200
# 3/3 [==============================] - 1s 287ms/step - loss: 0.5177 - accuracy: 0.8490 - val_loss: 0.7333 - val_accuracy: 0.6667
# Epoch 14/200
# 3/3 [==============================] - 1s 279ms/step - loss: 0.4697 - accuracy: 0.8438 - val_loss: 0.5424 - val_accuracy: 0.7500
# Epoch 15/200
# 3/3 [==============================] - 1s 251ms/step - loss: 0.5602 - accuracy: 0.8086 - val_loss: 0.8808 - val_accuracy: 0.7083
# Epoch 16/200
# 3/3 [==============================] - 1s 250ms/step - loss: 0.8733 - accuracy: 0.8086 - val_loss: 0.3261 - val_accuracy: 0.8750
# Epoch 17/200
# 3/3 [==============================] - 1s 258ms/step - loss: 0.4436 - accuracy: 0.8880 - val_loss: 0.6591 - val_accuracy: 0.7917
# Epoch 18/200
# 3/3 [==============================] - 1s 299ms/step - loss: 0.7494 - accuracy: 0.7747 - val_loss: 0.2384 - val_accuracy: 0.9583
# Epoch 19/200
# 3/3 [==============================] - 1s 289ms/step - loss: 0.6916 - accuracy: 0.7773 - val_loss: 0.2809 - val_accuracy: 0.8750
# Epoch 20/200
# 3/3 [==============================] - 1s 284ms/step - loss: 0.3980 - accuracy: 0.8411 - val_loss: 0.7843 - val_accuracy: 0.8333
# Epoch 21/200
# 3/3 [==============================] - 1s 335ms/step - loss: 0.2316 - accuracy: 0.8477 - val_loss: 0.2182 - val_accuracy: 0.9167
# Epoch 22/200
# 3/3 [==============================] - 1s 268ms/step - loss: 0.3254 - accuracy: 0.8685 - val_loss: 0.2318 - val_accuracy: 0.8333
# Epoch 23/200
# 3/3 [==============================] - 1s 255ms/step - loss: 0.3609 - accuracy: 0.8932 - val_loss: 0.2388 - val_accuracy: 0.9583
# Epoch 24/200
# 3/3 [==============================] - 1s 255ms/step - loss: 0.2209 - accuracy: 0.9062 - val_loss: 0.2696 - val_accuracy: 0.8750
# Epoch 25/200
# 3/3 [==============================] - 1s 275ms/step - loss: 0.2241 - accuracy: 0.9375 - val_loss: 0.2864 - val_accuracy: 0.8750
# Epoch 26/200
# 3/3 [==============================] - 1s 293ms/step - loss: 0.1602 - accuracy: 0.9622 - val_loss: 0.2504 - val_accuracy: 0.8750
# Epoch 27/200
# 3/3 [==============================] - 1s 289ms/step - loss: 0.4682 - accuracy: 0.8151 - val_loss: 0.2430 - val_accuracy: 0.8750
# Epoch 28/200
# 3/3 [==============================] - 1s 290ms/step - loss: 0.3787 - accuracy: 0.8867 - val_loss: 0.2353 - val_accuracy: 0.8750
# Epoch 29/200
# 3/3 [==============================] - 1s 279ms/step - loss: 0.2608 - accuracy: 0.8893 - val_loss: 0.2280 - val_accuracy: 0.9167
# Epoch 30/200
# 3/3 [==============================] - 1s 269ms/step - loss: 0.2549 - accuracy: 0.9219 - val_loss: 0.2185 - val_accuracy: 0.9167
# Epoch 31/200
# 3/3 [==============================] - 1s 280ms/step - loss: 0.3505 - accuracy: 0.8724 - val_loss: 0.2103 - val_accuracy: 0.9167
# Epoch 32/200
# 3/3 [==============================] - 1s 252ms/step - loss: 0.2263 - accuracy: 0.8854 - val_loss: 0.2017 - val_accuracy: 0.9167
# Epoch 33/200
# 3/3 [==============================] - 1s 290ms/step - loss: 0.2767 - accuracy: 0.8932 - val_loss: 0.1960 - val_accuracy: 0.8750
# Epoch 34/200
# 3/3 [==============================] - 1s 276ms/step - loss: 0.1959 - accuracy: 0.9271 - val_loss: 0.1880 - val_accuracy: 0.8750
# Epoch 35/200
# 3/3 [==============================] - 1s 280ms/step - loss: 0.2680 - accuracy: 0.8867 - val_loss: 0.1888 - val_accuracy: 0.8750
# Epoch 36/200
# 3/3 [==============================] - 1s 285ms/step - loss: 0.1934 - accuracy: 0.9466 - val_loss: 0.1874 - val_accuracy: 0.8750
# Epoch 37/200
# 3/3 [==============================] - 1s 292ms/step - loss: 0.1821 - accuracy: 0.9609 - val_loss: 0.1865 - val_accuracy: 0.8750
# Epoch 38/200
# 3/3 [==============================] - 1s 279ms/step - loss: 0.2135 - accuracy: 0.9141 - val_loss: 0.1844 - val_accuracy: 0.9167
# Epoch 39/200
# 3/3 [==============================] - 1s 346ms/step - loss: 0.2419 - accuracy: 0.9284 - val_loss: 0.1822 - val_accuracy: 0.9583
# Epoch 40/200
# 3/3 [==============================] - 1s 254ms/step - loss: 0.1422 - accuracy: 0.9570 - val_loss: 0.1806 - val_accuracy: 0.9583
# Epoch 41/200
# 3/3 [==============================] - 1s 278ms/step - loss: 0.1596 - accuracy: 0.9583 - val_loss: 0.1806 - val_accuracy: 0.9583
# Epoch 42/200
# 3/3 [==============================] - 1s 262ms/step - loss: 0.1641 - accuracy: 0.9414 - val_loss: 0.1803 - val_accuracy: 0.9583
# Epoch 43/200
# 3/3 [==============================] - 1s 271ms/step - loss: 0.3296 - accuracy: 0.9062 - val_loss: 0.1800 - val_accuracy: 0.9583
# Epoch 44/200
# 3/3 [==============================] - 1s 252ms/step - loss: 0.2000 - accuracy: 0.9219 - val_loss: 0.1780 - val_accuracy: 0.9583
# Epoch 45/200
# 3/3 [==============================] - 1s 281ms/step - loss: 0.2217 - accuracy: 0.9297 - val_loss: 0.1772 - val_accuracy: 0.9583
# Epoch 46/200
# 3/3 [==============================] - 1s 294ms/step - loss: 0.1972 - accuracy: 0.9583 - val_loss: 0.1775 - val_accuracy: 0.9583
# Epoch 47/200
# 3/3 [==============================] - 1s 260ms/step - loss: 0.2224 - accuracy: 0.8945 - val_loss: 0.1774 - val_accuracy: 0.9583
# Epoch 48/200
# 3/3 [==============================] - 1s 290ms/step - loss: 0.2063 - accuracy: 0.9375 - val_loss: 0.1772 - val_accuracy: 0.9583
# Epoch 49/200
# 3/3 [==============================] - 1s 353ms/step - loss: 0.2257 - accuracy: 0.9128 - val_loss: 0.1772 - val_accuracy: 0.9583
# Epoch 50/200
# 3/3 [==============================] - 1s 252ms/step - loss: 0.1825 - accuracy: 0.9648 - val_loss: 0.1763 - val_accuracy: 0.9583
# Epoch 51/200
# 3/3 [==============================] - 1s 306ms/step - loss: 0.1312 - accuracy: 0.9375 - val_loss: 0.1757 - val_accuracy: 0.9583
# Epoch 52/200
# 3/3 [==============================] - 1s 293ms/step - loss: 0.1509 - accuracy: 0.9505 - val_loss: 0.1752 - val_accuracy: 0.9583
# Epoch 53/200
# 3/3 [==============================] - 1s 253ms/step - loss: 0.2803 - accuracy: 0.9010 - val_loss: 0.1761 - val_accuracy: 0.9583
# Epoch 54/200
# 3/3 [==============================] - 1s 280ms/step - loss: 0.1858 - accuracy: 0.9206 - val_loss: 0.1762 - val_accuracy: 0.9583
# Epoch 55/200
# 3/3 [==============================] - 1s 263ms/step - loss: 0.1848 - accuracy: 0.9193 - val_loss: 0.1746 - val_accuracy: 0.9583
# Epoch 56/200
# 3/3 [==============================] - 1s 324ms/step - loss: 0.2027 - accuracy: 0.9466 - val_loss: 0.1730 - val_accuracy: 0.9583
# Epoch 57/200
# 3/3 [==============================] - 1s 285ms/step - loss: 0.0944 - accuracy: 0.9844 - val_loss: 0.1722 - val_accuracy: 0.9583
# Epoch 58/200
# 3/3 [==============================] - 1s 296ms/step - loss: 0.2869 - accuracy: 0.8893 - val_loss: 0.1725 - val_accuracy: 0.9583
# Epoch 59/200
# 3/3 [==============================] - 1s 294ms/step - loss: 0.2002 - accuracy: 0.9362 - val_loss: 0.1722 - val_accuracy: 0.9583
# Epoch 60/200
# 3/3 [==============================] - 1s 283ms/step - loss: 0.1701 - accuracy: 0.9271 - val_loss: 0.1721 - val_accuracy: 0.9583
# Epoch 61/200
# 3/3 [==============================] - 1s 272ms/step - loss: 0.1889 - accuracy: 0.9414 - val_loss: 0.1742 - val_accuracy: 0.9583
# Epoch 62/200
# 3/3 [==============================] - 1s 282ms/step - loss: 0.2081 - accuracy: 0.9427 - val_loss: 0.1772 - val_accuracy: 0.9583
# Epoch 63/200
# 3/3 [==============================] - 1s 288ms/step - loss: 0.1786 - accuracy: 0.9154 - val_loss: 0.1794 - val_accuracy: 0.9583
# Epoch 64/200
# 3/3 [==============================] - 1s 284ms/step - loss: 0.2580 - accuracy: 0.8789 - val_loss: 0.1795 - val_accuracy: 0.9583
# Epoch 65/200
# 3/3 [==============================] - 1s 277ms/step - loss: 0.1318 - accuracy: 0.9661 - val_loss: 0.1795 - val_accuracy: 0.9583
# Epoch 66/200
# 3/3 [==============================] - 1s 299ms/step - loss: 0.2477 - accuracy: 0.9036 - val_loss: 0.1798 - val_accuracy: 0.9583
# Epoch 67/200
# 3/3 [==============================] - 1s 263ms/step - loss: 0.1686 - accuracy: 0.9505 - val_loss: 0.1803 - val_accuracy: 0.9167
# Epoch 68/200
# 3/3 [==============================] - 1s 251ms/step - loss: 0.2129 - accuracy: 0.9583 - val_loss: 0.1810 - val_accuracy: 0.9167
# Epoch 69/200
# 3/3 [==============================] - 1s 294ms/step - loss: 0.1895 - accuracy: 0.9010 - val_loss: 0.1811 - val_accuracy: 0.9167
# Epoch 70/200
# 3/3 [==============================] - 1s 289ms/step - loss: 0.2612 - accuracy: 0.8997 - val_loss: 0.1808 - val_accuracy: 0.9167
# Epoch 71/200
# 3/3 [==============================] - 1s 325ms/step - loss: 0.1800 - accuracy: 0.9375 - val_loss: 0.1809 - val_accuracy: 0.9167
# Epoch 72/200
# 3/3 [==============================] - 1s 301ms/step - loss: 0.1707 - accuracy: 0.9544 - val_loss: 0.1809 - val_accuracy: 0.9167
# Epoch 73/200
# 3/3 [==============================] - 1s 287ms/step - loss: 0.1767 - accuracy: 0.9583 - val_loss: 0.1808 - val_accuracy: 0.9167
# Epoch 74/200
# 3/3 [==============================] - 1s 295ms/step - loss: 0.1589 - accuracy: 0.9635 - val_loss: 0.1808 - val_accuracy: 0.9167
# Epoch 75/200
# 3/3 [==============================] - 1s 287ms/step - loss: 0.1657 - accuracy: 0.9440 - val_loss: 0.1808 - val_accuracy: 0.9167
# Epoch 76/200
# 3/3 [==============================] - 1s 278ms/step - loss: 0.1374 - accuracy: 0.9753 - val_loss: 0.1808 - val_accuracy: 0.9167
# Epoch 77/200
# 3/3 [==============================] - 1s 302ms/step - loss: 0.2189 - accuracy: 0.9284 - val_loss: 0.1808 - val_accuracy: 0.9167
# Epoch 78/200
# 3/3 [==============================] - 1s 261ms/step - loss: 0.1367 - accuracy: 0.9427 - val_loss: 0.1808 - val_accuracy: 0.9167
# Epoch 79/200
# 3/3 [==============================] - 1s 340ms/step - loss: 0.2314 - accuracy: 0.8919 - val_loss: 0.1808 - val_accuracy: 0.9167
# Epoch 80/200
# 3/3 [==============================] - 1s 308ms/step - loss: 0.2250 - accuracy: 0.8919 - val_loss: 0.1808 - val_accuracy: 0.9167
# Epoch 81/200
# 3/3 [==============================] - 1s 301ms/step - loss: 0.2079 - accuracy: 0.9115 - val_loss: 0.1808 - val_accuracy: 0.9167
# Epoch 82/200
# 3/3 [==============================] - 1s 252ms/step - loss: 0.1824 - accuracy: 0.9167 - val_loss: 0.1808 - val_accuracy: 0.9167
# Epoch 83/200
# 3/3 [==============================] - 1s 275ms/step - loss: 0.1439 - accuracy: 0.9284 - val_loss: 0.1808 - val_accuracy: 0.9167
# Epoch 84/200
# 3/3 [==============================] - 1s 292ms/step - loss: 0.2158 - accuracy: 0.9453 - val_loss: 0.1808 - val_accuracy: 0.9167
# Epoch 85/200
# 3/3 [==============================] - 1s 274ms/step - loss: 0.1243 - accuracy: 0.9688 - val_loss: 0.1808 - val_accuracy: 0.9167
# Epoch 86/200
# 3/3 [==============================] - 1s 282ms/step - loss: 0.2851 - accuracy: 0.8997 - val_loss: 0.1808 - val_accuracy: 0.9167
# Epoch 87/200
# 3/3 [==============================] - 1s 254ms/step - loss: 0.2626 - accuracy: 0.8906 - val_loss: 0.1808 - val_accuracy: 0.9167
# Epoch 88/200
# 3/3 [==============================] - 1s 285ms/step - loss: 0.1550 - accuracy: 0.9128 - val_loss: 0.1808 - val_accuracy: 0.9167
# Epoch 89/200
# 3/3 [==============================] - 1s 252ms/step - loss: 0.1675 - accuracy: 0.9388 - val_loss: 0.1808 - val_accuracy: 0.9167
# Epoch 90/200
# 3/3 [==============================] - 1s 281ms/step - loss: 0.1861 - accuracy: 0.9440 - val_loss: 0.1808 - val_accuracy: 0.9167
# Epoch 91/200
# 3/3 [==============================] - 1s 315ms/step - loss: 0.2161 - accuracy: 0.8906 - val_loss: 0.1808 - val_accuracy: 0.9167
# Epoch 92/200
# 3/3 [==============================] - 1s 275ms/step - loss: 0.1628 - accuracy: 0.9362 - val_loss: 0.1808 - val_accuracy: 0.9167
# Epoch 93/200
# 3/3 [==============================] - 1s 271ms/step - loss: 0.2138 - accuracy: 0.9271 - val_loss: 0.1808 - val_accuracy: 0.9167
# Epoch 94/200
# 3/3 [==============================] - 1s 333ms/step - loss: 0.1271 - accuracy: 0.9609 - val_loss: 0.1808 - val_accuracy: 0.9167
# Epoch 95/200
# 3/3 [==============================] - 1s 298ms/step - loss: 0.3034 - accuracy: 0.8906 - val_loss: 0.1808 - val_accuracy: 0.9167
# Epoch 96/200
# 3/3 [==============================] - 1s 277ms/step - loss: 0.1670 - accuracy: 0.9531 - val_loss: 0.1808 - val_accuracy: 0.9167
# Epoch 97/200
# 3/3 [==============================] - 1s 309ms/step - loss: 0.1543 - accuracy: 0.9401 - val_loss: 0.1808 - val_accuracy: 0.9167
# Epoch 98/200
# 3/3 [==============================] - 1s 275ms/step - loss: 0.1571 - accuracy: 0.9453 - val_loss: 0.1808 - val_accuracy: 0.9167
# Epoch 99/200
# 3/3 [==============================] - 1s 252ms/step - loss: 0.1898 - accuracy: 0.9102 - val_loss: 0.1808 - val_accuracy: 0.9167
# Epoch 100/200
# 3/3 [==============================] - 1s 266ms/step - loss: 0.2249 - accuracy: 0.9206 - val_loss: 0.1808 - val_accuracy: 0.9167

# %%
model.save('VGG_40imgs.h5')

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# ## Test

# %%
test_datagen = ImageDataGenerator()#rescale = 1./255)#Rescaling(1./255, input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)))
test_batches = test_datagen.flow_from_dataframe(
    df_test, 
    directory=dir,
    x_col='ImageID',y_col='Projection',
    target_size=IMAGE_SIZE,
    shuffle=False,
    batch_size=1,
    seed=42,
    class_mode="categorical"#, validate_filenames=False
    )
# Out:
# Found 4360 validated image filenames belonging to 3 classes.

# %%
model = load_model('VGG_40imgs.h5')

# %%
#Calculamos la matriz de predicciones
result_test=model.predict(test_batches, verbose=1)
print(result_test.shape)
# Out:
# 4360/4360 [==============================] - 2248s 516ms/step
# (4360, 3)

# %%
#Calculamos la matriz de predicciones
#result_test=model.predict(test_batches, verbose=1)
print ("Loss = " + str(result_test[0]))
print ("Test Accuracy = " + str(result_test[1]))
# Out:
# Loss = [2.7191447e-04 1.5200284e-05 9.9971288e-01]
# Test Accuracy = [0.13065182 0.02575747 0.84359074]

# %%
#Obtenemos el nombre de clase asociado a cada indice
classes_dict = dict(zip(train_batches.class_indices.values(),train_batches.class_indices.keys()))
classes_dict
# Out:
# {0: 'AP_horizontal', 1: 'L', 2: 'PA'}

# %%
#Obtenemos el índice de mayor score en cada fila (cada imagen)
preds = result_test.argmax(axis=-1)

# %%
#Obtenemos el nombre de clase asignado a cada clase
preds_classes = [classes_dict[p] for p in preds]

# %%
# A qué clase asigna cada imagen
preds_classes

# %%
#Evaluar cuantas predicciones hay de cada clase
pd.Series(preds_classes).value_counts()
# Out:
# PA               2492
# L                1474
# AP_horizontal     394
# dtype: int64

# %%
import numpy as np
#Obtenemos el nombre de clase de la etiqueta verdadera (groun-truths)
gts = np.array([classes_dict[p] for p in test_batches.classes])

# %% [markdown]
# # Resultados

# %% [markdown]
# ## Reporte de clasificación

# %%
#Evaluamos métricas de clasificación
from sklearn.metrics import classification_report, confusion_matrix

print(classification_report(gts,preds_classes))
# Out:
#                precision    recall  f1-score   support
#
# AP_horizontal       0.47      0.85      0.60       217
#             L       0.96      0.99      0.97      1427
#            PA       0.99      0.91      0.95      2716
#
#      accuracy                           0.93      4360
#     macro avg       0.80      0.91      0.84      4360
#  weighted avg       0.95      0.93      0.94      4360

# %% [markdown]
# ## Matriz de Confusión

# %%
def plot_confusion_matrix(cm, classes,
                          title='Matriz de confusión',
                          cmap=plt.cm.Blues):
    plt.figure(figsize=(8,8))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, fontsize=20)
    plt.yticks(tick_marks, classes, fontsize=20)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center", fontsize=20,
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('Etiqueta verdadera', fontsize=20)
    plt.xlabel('Predicción del modelo', fontsize=20)
    plt.show()

# %%
confusionMatrix = confusion_matrix(gts,preds_classes)

plot_confusion_matrix(confusionMatrix,test_batches.class_indices.keys())

# %% [markdown]
# ##Curvas AUC ROC y Precision Recall

# %%
import numpy as np
from scipy import interp
import matplotlib.pyplot as plt
from itertools import cycle
from sklearn.metrics import roc_curve, auc

# %%
y_test = pd.get_dummies(gts).to_numpy()

# %%
y_score = result_test
# Plot linewidth.
lw = 2

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(NUM_CLASSES):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Compute macro-average ROC curve and ROC area

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(NUM_CLASSES)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(NUM_CLASSES):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= NUM_CLASSES

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure(1)
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(NUM_CLASSES), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Some extension of Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")
plt.show()


# Zoom in view of the upper left corner.
plt.figure(2)
plt.xlim(0, 0.2)
plt.ylim(0.8, 1)
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(NUM_CLASSES), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Some extension of Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead

# %%
Y_test = pd.get_dummies(gts).to_numpy()
y_score = result_test

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score

# For each class
precision = dict()
recall = dict()
average_precision = dict()
for i in range(NUM_CLASSES):
    precision[i], recall[i], _ = precision_recall_curve(Y_test[:, i],
                                                        y_score[:, i])
    average_precision[i] = average_precision_score(Y_test[:, i], y_score[:, i])


# A "micro-average": quantifying score on all classes jointly
precision["micro"], recall["micro"], _ = precision_recall_curve(Y_test.ravel(),
    y_score.ravel())
average_precision["micro"] = average_precision_score(Y_test, y_score,
                                                     average="micro")
print('Average precision score, micro-averaged over all classes: {0:0.2f}'
      .format(average_precision["micro"]))
# Out:
# Average precision score, micro-averaged over all classes: 0.97

# %%
plt.figure()
plt.step(recall['micro'], precision['micro'], where='post')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title(
    'Average precision score, micro-averaged over all classes: AP={0:0.2f}'
    .format(average_precision["micro"]))
# Out:
# Text(0.5, 1.0, 'Average precision score, micro-averaged over all classes: AP=0.93')

# %%
from itertools import cycle
# setup plot details
colors = cycle(['navy', 'turquoise', 'darkorange', 'cornflowerblue', 'teal'])

plt.figure(figsize=(7, 8))
f_scores = np.linspace(0.2, 0.8, num=4)
lines = []
labels = []
for f_score in f_scores:
    x = np.linspace(0.01, 1)
    y = f_score * x / (2 * x - f_score)
    l, = plt.plot(x[y >= 0], y[y >= 0], color='gray', alpha=0.2)
    plt.annotate('f1={0:0.1f}'.format(f_score), xy=(0.9, y[45] + 0.02))

lines.append(l)
labels.append('iso-f1 curves')
l, = plt.plot(recall["micro"], precision["micro"], color='gold', lw=2)
lines.append(l)
labels.append('micro-average Precision-recall (area = {0:0.2f})'
              ''.format(average_precision["micro"]))

for i, color in zip(range(NUM_CLASSES), colors):
    l, = plt.plot(recall[i], precision[i], color=color, lw=2)
    lines.append(l)
    labels.append('Precision-recall for class {0} (area = {1:0.2f})'
                  ''.format(i, average_precision[i]))

fig = plt.gcf()
fig.subplots_adjust(bottom=0.25)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Extension of Precision-Recall curve to multi-class')
plt.legend(lines, labels, loc=(0, -.38), prop=dict(size=14))


plt.show()
