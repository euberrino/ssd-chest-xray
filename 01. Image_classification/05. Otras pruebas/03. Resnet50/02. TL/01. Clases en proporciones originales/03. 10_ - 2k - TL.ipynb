# %% [markdown]
# #Montaje e Importación de Librerías

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/2020 - Quinto Anio/TESIS_Eugenia_Berrino
# Out:
# /content/drive/MyDrive/2020 - Quinto Anio/TESIS_Eugenia_Berrino

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Flatten, Dense, Dropout,GlobalAveragePooling2D
from tensorflow.keras import Sequential
from tensorflow.keras.layers.experimental.preprocessing import RandomRotation,RandomFlip,Rescaling
from tensorflow.keras.callbacks import EarlyStopping , ReduceLROnPlateau
import shutil
from tensorflow.keras.models import load_model, Model, Sequential
from sklearn.metrics import classification_report, confusion_matrix
import itertools
from matplotlib import pyplot as plt
from keras import applications

# %% [markdown]
# #El Modelo
#
# https://towardsdatascience.com/understanding-and-coding-a-resnet-in-keras-446d7ff84d33
# https://github.com/priya-dwivedi/Deep-Learning/tree/master/resnet_keras

# %% [markdown]
# ## Definiciones, Importacion de imágenes

# %%
IMAGE_SIZE = (128,128)
NUM_CLASSES = 3 
BATCH_SIZE = 32

# %%
df_train=pd.read_excel("train0-7_10%.xlsx")
df_test=pd.read_excel("test0-7.xlsx")

# %%
train_datagen = ImageDataGenerator(validation_split = 0.2,rescale = 1./255,horizontal_flip=True,rotation_range=40)
dir = '/content/drive/My Drive/2020 - Quinto Anio/TESIS_Eugenia_Berrino/DS_comp_nodef'
train_batches = train_datagen.flow_from_dataframe( #tomamos info de un df
    df_train, 
    directory=dir,
    x_col='ImageID',y_col='Projection',
    target_size=IMAGE_SIZE,
    shuffle=True,
    batch_size=BATCH_SIZE,
    subset = "training",
    seed=42,
    class_mode="categorical",)
# Out:
# Found 1450 validated image filenames belonging to 3 classes.

# %%
valid_batches = train_datagen.flow_from_dataframe(df_train, directory=dir,
                                            x_col='ImageID',y_col='Projection',
                                            target_size=IMAGE_SIZE,
                                            shuffle=True,
                                            batch_size=BATCH_SIZE,
                                            subset = "validation",
                                            seed=42,
                                            class_mode="categorical",)
# Out:
# Found 362 validated image filenames belonging to 3 classes.

# %%
base_model = applications.resnet50.ResNet50(weights= 'imagenet', include_top=False, input_shape= (IMAGE_SIZE[0], IMAGE_SIZE[1], 3) ) #weights= None
#model.add(data_augmentation)
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.5)(x)
predictions = Dense(NUM_CLASSES , activation= 'softmax')(x)
model = Model(inputs = base_model.input, outputs = predictions)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step

# %%
from keras.optimizers import SGD, Adam
# sgd = SGD(lr=lrate, momentum=0.9, decay=decay, nesterov=False)
adam = Adam(lr=0.001) #0.001
model.compile(optimizer= adam, loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ##Train

# %%
history = model.fit(train_batches, validation_data = valid_batches , epochs = 100,workers=8, callbacks=[EarlyStopping(monitor='val_loss',patience=15,restore_best_weights=True),ReduceLROnPlateau(monitor='val_loss',factor = 0.1,patience=5,min_lr=0)], batch_size = BATCH_SIZE)
# Out:
# Epoch 1/100
# 46/46 [==============================] - 96s 2s/step - loss: 0.3402 - accuracy: 0.8951 - val_loss: 1986.4554 - val_accuracy: 0.6160
# Epoch 2/100
# 46/46 [==============================] - 17s 328ms/step - loss: 0.1773 - accuracy: 0.9553 - val_loss: 20.8091 - val_accuracy: 0.3149
# Epoch 3/100
# 46/46 [==============================] - 17s 335ms/step - loss: 0.2696 - accuracy: 0.9348 - val_loss: 13.1337 - val_accuracy: 0.3149
# Epoch 4/100
# 46/46 [==============================] - 17s 331ms/step - loss: 0.1122 - accuracy: 0.9659 - val_loss: 1.6261 - val_accuracy: 0.3149
# Epoch 5/100
# 46/46 [==============================] - 17s 339ms/step - loss: 0.0707 - accuracy: 0.9769 - val_loss: 1.3013 - val_accuracy: 0.3149
# Epoch 6/100
# 46/46 [==============================] - 17s 332ms/step - loss: 0.0919 - accuracy: 0.9687 - val_loss: 5.2323 - val_accuracy: 0.3149
# Epoch 7/100
# 46/46 [==============================] - 17s 335ms/step - loss: 0.0417 - accuracy: 0.9875 - val_loss: 12.9457 - val_accuracy: 0.3149
# Epoch 8/100
# 46/46 [==============================] - 17s 330ms/step - loss: 0.0400 - accuracy: 0.9892 - val_loss: 1.4008 - val_accuracy: 0.3149
# Epoch 9/100
# 46/46 [==============================] - 17s 329ms/step - loss: 0.0509 - accuracy: 0.9881 - val_loss: 144.0949 - val_accuracy: 0.0691
# Epoch 10/100
# 46/46 [==============================] - 17s 330ms/step - loss: 0.0381 - accuracy: 0.9900 - val_loss: 1.0321 - val_accuracy: 0.3149
# Epoch 11/100
# 46/46 [==============================] - 17s 335ms/step - loss: 0.0486 - accuracy: 0.9871 - val_loss: 2.7304 - val_accuracy: 0.3453
# Epoch 12/100
# 46/46 [==============================] - 17s 329ms/step - loss: 0.0284 - accuracy: 0.9947 - val_loss: 3.3197 - val_accuracy: 0.3149
# Epoch 13/100
# 46/46 [==============================] - 17s 332ms/step - loss: 0.0292 - accuracy: 0.9929 - val_loss: 4.4140 - val_accuracy: 0.3149
# Epoch 14/100
# 46/46 [==============================] - 17s 337ms/step - loss: 0.0378 - accuracy: 0.9867 - val_loss: 5.6501 - val_accuracy: 0.3149
# Epoch 15/100
# 46/46 [==============================] - 17s 327ms/step - loss: 0.0769 - accuracy: 0.9830 - val_loss: 6.9282 - val_accuracy: 0.3149
# Epoch 16/100
# 46/46 [==============================] - 17s 336ms/step - loss: 0.0413 - accuracy: 0.9902 - val_loss: 6.8054 - val_accuracy: 0.3149
# Epoch 17/100
# 46/46 [==============================] - 17s 333ms/step - loss: 0.0170 - accuracy: 0.9968 - val_loss: 5.1549 - val_accuracy: 0.3149
# Epoch 18/100
# 46/46 [==============================] - 17s 334ms/step - loss: 0.0254 - accuracy: 0.9932 - val_loss: 3.4886 - val_accuracy: 0.3260
# Epoch 19/100
# 46/46 [==============================] - 18s 331ms/step - loss: 0.0241 - accuracy: 0.9914 - val_loss: 2.1451 - val_accuracy: 0.3646
# Epoch 20/100
# 46/46 [==============================] - 17s 337ms/step - loss: 0.0154 - accuracy: 0.9967 - val_loss: 1.9908 - val_accuracy: 0.4088
# Epoch 21/100
# 46/46 [==============================] - 17s 336ms/step - loss: 0.0196 - accuracy: 0.9960 - val_loss: 1.7865 - val_accuracy: 0.4972
# Epoch 22/100
# 46/46 [==============================] - 17s 334ms/step - loss: 0.0153 - accuracy: 0.9973 - val_loss: 1.2875 - val_accuracy: 0.6215
# Epoch 23/100
# 46/46 [==============================] - 17s 339ms/step - loss: 0.0163 - accuracy: 0.9938 - val_loss: 0.5357 - val_accuracy: 0.8370
# Epoch 24/100
# 46/46 [==============================] - 17s 330ms/step - loss: 0.0176 - accuracy: 0.9935 - val_loss: 0.2308 - val_accuracy: 0.9227
# Epoch 25/100
# 46/46 [==============================] - 17s 334ms/step - loss: 0.0130 - accuracy: 0.9952 - val_loss: 0.1114 - val_accuracy: 0.9696
# Epoch 26/100
# 46/46 [==============================] - 17s 330ms/step - loss: 0.0290 - accuracy: 0.9936 - val_loss: 0.0522 - val_accuracy: 0.9751
# Epoch 27/100
# 46/46 [==============================] - 17s 328ms/step - loss: 0.0238 - accuracy: 0.9930 - val_loss: 0.0130 - val_accuracy: 0.9945
# Epoch 28/100
# 46/46 [==============================] - 17s 333ms/step - loss: 0.0175 - accuracy: 0.9928 - val_loss: 0.0078 - val_accuracy: 0.9972
# Epoch 29/100
# 46/46 [==============================] - 18s 334ms/step - loss: 0.0186 - accuracy: 0.9949 - val_loss: 0.0070 - val_accuracy: 0.9972
# Epoch 30/100
# 46/46 [==============================] - 17s 335ms/step - loss: 0.0172 - accuracy: 0.9938 - val_loss: 0.0082 - val_accuracy: 0.9972
# Epoch 31/100
# 46/46 [==============================] - 17s 332ms/step - loss: 0.0239 - accuracy: 0.9960 - val_loss: 0.0076 - val_accuracy: 0.9972
# Epoch 32/100
# 46/46 [==============================] - 17s 334ms/step - loss: 0.0191 - accuracy: 0.9957 - val_loss: 0.0057 - val_accuracy: 0.9972
# Epoch 33/100
# 46/46 [==============================] - 17s 336ms/step - loss: 0.0199 - accuracy: 0.9938 - val_loss: 0.0052 - val_accuracy: 0.9972
# Epoch 34/100
# 46/46 [==============================] - 18s 331ms/step - loss: 0.0099 - accuracy: 0.9977 - val_loss: 0.0077 - val_accuracy: 0.9972
# Epoch 35/100
# 46/46 [==============================] - 17s 335ms/step - loss: 0.0219 - accuracy: 0.9938 - val_loss: 0.0056 - val_accuracy: 0.9972
# Epoch 36/100
# 46/46 [==============================] - 17s 334ms/step - loss: 0.0181 - accuracy: 0.9955 - val_loss: 0.0052 - val_accuracy: 0.9972
# Epoch 37/100
# 46/46 [==============================] - 17s 330ms/step - loss: 0.0340 - accuracy: 0.9921 - val_loss: 0.0084 - val_accuracy: 0.9972
# Epoch 38/100
# 46/46 [==============================] - 18s 334ms/step - loss: 0.0148 - accuracy: 0.9971 - val_loss: 0.0099 - val_accuracy: 0.9972
# Epoch 39/100
# 46/46 [==============================] - 18s 330ms/step - loss: 0.0116 - accuracy: 0.9974 - val_loss: 0.0059 - val_accuracy: 0.9972
# Epoch 40/100
# 46/46 [==============================] - 19s 336ms/step - loss: 0.0156 - accuracy: 0.9939 - val_loss: 0.0109 - val_accuracy: 0.9972
# Epoch 41/100
# 46/46 [==============================] - 17s 331ms/step - loss: 0.0223 - accuracy: 0.9948 - val_loss: 0.0076 - val_accuracy: 0.9972
# Epoch 42/100
# 46/46 [==============================] - 17s 334ms/step - loss: 0.0189 - accuracy: 0.9919 - val_loss: 0.0049 - val_accuracy: 0.9972
# Epoch 43/100
# 46/46 [==============================] - 17s 336ms/step - loss: 0.0119 - accuracy: 0.9962 - val_loss: 0.0059 - val_accuracy: 0.9972
# Epoch 44/100
# 46/46 [==============================] - 17s 334ms/step - loss: 0.0133 - accuracy: 0.9962 - val_loss: 0.0072 - val_accuracy: 0.9972
# Epoch 45/100
# 46/46 [==============================] - 17s 335ms/step - loss: 0.0201 - accuracy: 0.9936 - val_loss: 0.0115 - val_accuracy: 0.9972
# Epoch 46/100
# 46/46 [==============================] - 17s 329ms/step - loss: 0.0205 - accuracy: 0.9951 - val_loss: 0.0084 - val_accuracy: 0.9945
# Epoch 47/100
# 46/46 [==============================] - 17s 334ms/step - loss: 0.0166 - accuracy: 0.9938 - val_loss: 0.0061 - val_accuracy: 0.9972
# Epoch 48/100
# 46/46 [==============================] - 17s 332ms/step - loss: 0.0159 - accuracy: 0.9962 - val_loss: 0.0048 - val_accuracy: 0.9972
# Epoch 49/100
# 46/46 [==============================] - 18s 338ms/step - loss: 0.0110 - accuracy: 0.9949 - val_loss: 0.0055 - val_accuracy: 0.9972
# Epoch 50/100
# 46/46 [==============================] - 17s 334ms/step - loss: 0.0162 - accuracy: 0.9971 - val_loss: 0.0084 - val_accuracy: 0.9972
# Epoch 51/100
# 46/46 [==============================] - 17s 331ms/step - loss: 0.0100 - accuracy: 0.9969 - val_loss: 0.0056 - val_accuracy: 0.9972
# Epoch 52/100
# 46/46 [==============================] - 17s 338ms/step - loss: 0.0147 - accuracy: 0.9959 - val_loss: 0.0049 - val_accuracy: 0.9972
# Epoch 53/100
# 46/46 [==============================] - 17s 333ms/step - loss: 0.0119 - accuracy: 0.9965 - val_loss: 0.0065 - val_accuracy: 0.9972
# Epoch 54/100
# 46/46 [==============================] - 17s 331ms/step - loss: 0.0108 - accuracy: 0.9966 - val_loss: 0.0068 - val_accuracy: 0.9972
# Epoch 55/100
# 46/46 [==============================] - 17s 332ms/step - loss: 0.0157 - accuracy: 0.9970 - val_loss: 0.0070 - val_accuracy: 0.9972
# Epoch 56/100
# 46/46 [==============================] - 17s 330ms/step - loss: 0.0246 - accuracy: 0.9937 - val_loss: 0.0068 - val_accuracy: 0.9972
# Epoch 57/100
# 46/46 [==============================] - 17s 335ms/step - loss: 0.0129 - accuracy: 0.9950 - val_loss: 0.0080 - val_accuracy: 0.9972
# Epoch 58/100
# 46/46 [==============================] - 17s 334ms/step - loss: 0.0111 - accuracy: 0.9979 - val_loss: 0.0071 - val_accuracy: 0.9972
# Epoch 59/100
# 46/46 [==============================] - 17s 336ms/step - loss: 0.0168 - accuracy: 0.9923 - val_loss: 0.0076 - val_accuracy: 0.9972
# Epoch 60/100
# 46/46 [==============================] - 17s 339ms/step - loss: 0.0177 - accuracy: 0.9943 - val_loss: 0.0079 - val_accuracy: 0.9972
# Epoch 61/100
# 46/46 [==============================] - 17s 333ms/step - loss: 0.0146 - accuracy: 0.9969 - val_loss: 0.0074 - val_accuracy: 0.9972
# Epoch 62/100
# 46/46 [==============================] - 19s 335ms/step - loss: 0.0208 - accuracy: 0.9938 - val_loss: 0.0071 - val_accuracy: 0.9972
# Epoch 63/100
# 46/46 [==============================] - 17s 333ms/step - loss: 0.0199 - accuracy: 0.9952 - val_loss: 0.0053 - val_accuracy: 0.9972

# %%
model.save('ResNet2_10%.h5')

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# ##Test

# %%
dir = '/content/drive/My Drive/2020 - Quinto Anio/TESIS_Eugenia_Berrino/DS_comp_nodef'
test_datagen = ImageDataGenerator(rescale = 1./255)#Rescaling(1./255, input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)))
test_batches = test_datagen.flow_from_dataframe(
    df_test, 
    directory=dir,
    x_col='ImageID',y_col='Projection',
    target_size=IMAGE_SIZE,
    shuffle=False,
    batch_size=1,
    seed=42,
    class_mode="categorical"#, validate_filenames=False
    )
# Out:
# Found 4360 validated image filenames belonging to 3 classes.

# %%
model = load_model('ResNet2_10%.h5')

# %%
#Calculamos la matriz de predicciones
result_test=model.predict(test_batches, verbose=1)
print(result_test.shape)
# Out:
# 4360/4360 [==============================] - 989s 225ms/step
# (4360, 3)

# %%
#Calculamos la matriz de predicciones
#result_test=model.predict(test_batches, verbose=1)
print ("Loss = " + str(result_test[0]))
print ("Test Accuracy = " + str(result_test[1]))
# Out:
# Loss = [5.7988494e-08 9.0551566e-08 9.9999988e-01]
# Test Accuracy = [2.8278047e-16 5.1351385e-18 1.0000000e+00]

# %%
#Obtenemos el nombre de clase asociado a cada indice
classes_dict = dict(zip(test_batches.class_indices.values(),test_batches.class_indices.keys()))
classes_dict
# Out:
# {0: 'AP_horizontal', 1: 'L', 2: 'PA'}

# %%
#Obtenemos el índice de mayor score en cada fila (cada imagen)
preds = result_test.argmax(axis=-1)

# %%
#Obtenemos el nombre de clase asignado a cada clase
preds_classes = [classes_dict[p] for p in preds]

# %%
# A qué clase asigna cada imagen
preds_classes

# %% [markdown]
# #Resultados

# %%
#Evaluar cuantas predicciones hay de cada clase
pd.Series(preds_classes).value_counts()
# Out:
# PA               2723
# L                1446
# AP_horizontal     191
# dtype: int64

# %%
import numpy as np
#Obtenemos el nombre de clase de la etiqueta verdadera (groun-truths)
gts = np.array([classes_dict[p] for p in test_batches.classes])

# %% [markdown]
# ##Classification Report

# %%
#Evaluamos métricas de clasificación
from sklearn.metrics import classification_report, confusion_matrix

print(classification_report(gts,preds_classes))
# Out:
#                precision    recall  f1-score   support
#
# AP_horizontal       0.99      0.87      0.93       217
#             L       0.99      1.00      0.99      1427
#            PA       0.99      0.99      0.99      2716
#
#      accuracy                           0.99      4360
#     macro avg       0.99      0.95      0.97      4360
#  weighted avg       0.99      0.99      0.99      4360

# %% [markdown]
# ##Matriz de Confusion

# %%
def plot_confusion_matrix(cm, classes,
                          title='Matriz de confusión',
                          cmap=plt.cm.Blues):
    plt.figure(figsize=(8,8))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, fontsize=20)
    plt.yticks(tick_marks, classes, fontsize=20)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center", fontsize=20,
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('Etiqueta verdadera', fontsize=20)
    plt.xlabel('Predicción del modelo', fontsize=20)
    plt.show()

# %%
confusionMatrix = confusion_matrix(gts,preds_classes)

plot_confusion_matrix(confusionMatrix,test_batches.class_indices.keys())

# %% [markdown]
# En este caso, podemos ver que el modelo no aprendió, se limitó a clasificar a todas las imágenes como pertenecientes a una sola clase.

# %% [markdown]
# ## Curvas AUC ROC y Precision Recall

# %%
import numpy as np
from scipy import interp
import matplotlib.pyplot as plt
from itertools import cycle
from sklearn.metrics import roc_curve, auc

# %%
y_test = pd.get_dummies(gts).to_numpy()

# %%
y_score = result_test
# Plot linewidth.
lw = 2

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(NUM_CLASSES):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Compute macro-average ROC curve and ROC area

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(NUM_CLASSES)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(NUM_CLASSES):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= NUM_CLASSES

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure(1)
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(NUM_CLASSES), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Some extension of Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")
plt.show()


# Zoom in view of the upper left corner.
plt.figure(2)
plt.xlim(0, 0.2)
plt.ylim(0.8, 1)
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(NUM_CLASSES), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Some extension of Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead

# %%
Y_test = pd.get_dummies(gts).to_numpy()
y_score = result_test

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score

# For each class
precision = dict()
recall = dict()
average_precision = dict()
for i in range(NUM_CLASSES):
    precision[i], recall[i], _ = precision_recall_curve(Y_test[:, i],
                                                        y_score[:, i])
    average_precision[i] = average_precision_score(Y_test[:, i], y_score[:, i])


# A "micro-average": quantifying score on all classes jointly
precision["micro"], recall["micro"], _ = precision_recall_curve(Y_test.ravel(),
    y_score.ravel())
average_precision["micro"] = average_precision_score(Y_test, y_score,
                                                     average="micro")
print('Average precision score, micro-averaged over all classes: {0:0.2f}'
      .format(average_precision["micro"]))
# Out:
# Average precision score, micro-averaged over all classes: 1.00

# %%
plt.figure()
plt.step(recall['micro'], precision['micro'], where='post')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title(
    'Average precision score, micro-averaged over all classes: AP={0:0.2f}'
    .format(average_precision["micro"]))
# Out:
# Text(0.5, 1.0, 'Average precision score, micro-averaged over all classes: AP=1.00')

# %%
from itertools import cycle
# setup plot details
colors = cycle(['navy', 'turquoise', 'darkorange', 'cornflowerblue', 'teal'])

plt.figure(figsize=(7, 8))
f_scores = np.linspace(0.2, 0.8, num=4)
lines = []
labels = []
for f_score in f_scores:
    x = np.linspace(0.01, 1)
    y = f_score * x / (2 * x - f_score)
    l, = plt.plot(x[y >= 0], y[y >= 0], color='gray', alpha=0.2)
    plt.annotate('f1={0:0.1f}'.format(f_score), xy=(0.9, y[45] + 0.02))

lines.append(l)
labels.append('iso-f1 curves')
l, = plt.plot(recall["micro"], precision["micro"], color='gold', lw=2)
lines.append(l)
labels.append('micro-average Precision-recall (area = {0:0.2f})'
              ''.format(average_precision["micro"]))

for i, color in zip(range(NUM_CLASSES), colors):
    l, = plt.plot(recall[i], precision[i], color=color, lw=2)
    lines.append(l)
    labels.append('Precision-recall for class {0} (area = {1:0.2f})'
                  ''.format(i, average_precision[i]))

fig = plt.gcf()
fig.subplots_adjust(bottom=0.25)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Extension of Precision-Recall curve to multi-class')
plt.legend(lines, labels, loc=(0, -.38), prop=dict(size=14))


plt.show()
