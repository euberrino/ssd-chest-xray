# %% [markdown]
# # Montaje e Importación de Librerías

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/2020 - Quinto Anio/TESIS_Eugenia_Berrino
# Out:
# /content/drive/MyDrive/2020 - Quinto Anio/TESIS_Eugenia_Berrino

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Flatten, Dense, Dropout,GlobalAveragePooling2D
from tensorflow.keras import Sequential
from tensorflow.keras.layers.experimental.preprocessing import RandomRotation,RandomFlip,Rescaling
from tensorflow.keras.callbacks import EarlyStopping , ReduceLROnPlateau
import shutil
from tensorflow.keras.models import load_model, Model, Sequential
from sklearn.metrics import classification_report, confusion_matrix
import itertools
from matplotlib import pyplot as plt
from keras import applications

# %% [markdown]
# #El modelo
#
# https://towardsdatascience.com/understanding-and-coding-a-resnet-in-keras-446d7ff84d33
# https://github.com/priya-dwivedi/Deep-Learning/tree/master/resnet_keras

# %%
IMAGE_SIZE = (128,128)
NUM_CLASSES = 3 
BATCH_SIZE = 32

# %%
df_train=pd.read_excel("train0-7_10%.xlsx")
df_test=pd.read_excel("test0-7.xlsx")

# %%
train_datagen = ImageDataGenerator(validation_split = 0.2,rescale = 1./255,horizontal_flip=True,rotation_range=40)
dir = '/content/drive/My Drive/2020 - Quinto Anio/TESIS_Eugenia_Berrino/DS_comp_nodef'
train_batches = train_datagen.flow_from_dataframe( #tomamos info de un df
    df_train, 
    directory=dir,
    x_col='ImageID',y_col='Projection',
    target_size=IMAGE_SIZE,
    shuffle=True,
    batch_size=BATCH_SIZE,
    subset = "training",
    seed=42,
    class_mode="categorical",)
# Out:
# Found 1450 validated image filenames belonging to 3 classes.

# %%
valid_batches = train_datagen.flow_from_dataframe(df_train, directory=dir,
                                            x_col='ImageID',y_col='Projection',
                                            target_size=IMAGE_SIZE,
                                            shuffle=True,
                                            batch_size=BATCH_SIZE,
                                            subset = "validation",
                                            seed=42,
                                            class_mode="categorical",)
# Out:
# Found 362 validated image filenames belonging to 3 classes.

# %%
base_model = applications.resnet50.ResNet50(weights= None, include_top=False, input_shape= (IMAGE_SIZE[0], IMAGE_SIZE[1], 3) ) 
#model.add(data_augmentation)
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.7)(x)
predictions = Dense(NUM_CLASSES , activation= 'softmax')(x)
model = Model(inputs = base_model.input, outputs = predictions)

# %%
from keras.optimizers import SGD, Adam
# sgd = SGD(lr=lrate, momentum=0.9, decay=decay, nesterov=False)
adam = Adam(lr=0.0001) #0.001
model.compile(optimizer= adam, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(train_batches, validation_data = valid_batches , epochs = 200,workers=8, callbacks=[EarlyStopping(monitor='val_loss',patience=40,restore_best_weights=True),ReduceLROnPlateau(monitor='val_loss',factor = 0.1,patience=5,min_lr=0)], batch_size = BATCH_SIZE)
# Out:
# Epoch 1/200
# 46/46 [==============================] - 88s 2s/step - loss: 1.6841 - accuracy: 0.5314 - val_loss: 0.9038 - val_accuracy: 0.6160
# Epoch 2/200
# 46/46 [==============================] - 17s 335ms/step - loss: 0.8336 - accuracy: 0.7807 - val_loss: 0.9877 - val_accuracy: 0.6160
# Epoch 3/200
# 46/46 [==============================] - 17s 331ms/step - loss: 0.5515 - accuracy: 0.8634 - val_loss: 2.7164 - val_accuracy: 0.6160
# Epoch 4/200
# 46/46 [==============================] - 17s 339ms/step - loss: 0.4258 - accuracy: 0.8932 - val_loss: 1.0130 - val_accuracy: 0.6271
# Epoch 5/200
# 46/46 [==============================] - 18s 346ms/step - loss: 0.3589 - accuracy: 0.9217 - val_loss: 4.6816 - val_accuracy: 0.3149
# Epoch 6/200
# 46/46 [==============================] - 17s 337ms/step - loss: 0.3039 - accuracy: 0.9223 - val_loss: 4.2449 - val_accuracy: 0.0773
# Epoch 7/200
# 46/46 [==============================] - 17s 330ms/step - loss: 0.2178 - accuracy: 0.9330 - val_loss: 4.8441 - val_accuracy: 0.0691
# Epoch 8/200
# 46/46 [==============================] - 17s 336ms/step - loss: 0.2478 - accuracy: 0.9232 - val_loss: 4.4514 - val_accuracy: 0.0884
# Epoch 9/200
# 46/46 [==============================] - 17s 336ms/step - loss: 0.2216 - accuracy: 0.9419 - val_loss: 3.3774 - val_accuracy: 0.2680
# Epoch 10/200
# 46/46 [==============================] - 17s 340ms/step - loss: 0.1993 - accuracy: 0.9494 - val_loss: 2.3301 - val_accuracy: 0.3646
# Epoch 11/200
# 46/46 [==============================] - 17s 345ms/step - loss: 0.2765 - accuracy: 0.9269 - val_loss: 1.3611 - val_accuracy: 0.5083
# Epoch 12/200
# 46/46 [==============================] - 17s 337ms/step - loss: 0.2058 - accuracy: 0.9424 - val_loss: 0.6515 - val_accuracy: 0.7293
# Epoch 13/200
# 46/46 [==============================] - 17s 336ms/step - loss: 0.2055 - accuracy: 0.9438 - val_loss: 0.3206 - val_accuracy: 0.8729
# Epoch 14/200
# 46/46 [==============================] - 18s 336ms/step - loss: 0.2578 - accuracy: 0.9287 - val_loss: 0.2203 - val_accuracy: 0.9199
# Epoch 15/200
# 46/46 [==============================] - 18s 342ms/step - loss: 0.2008 - accuracy: 0.9487 - val_loss: 0.1439 - val_accuracy: 0.9475
# Epoch 16/200
# 46/46 [==============================] - 17s 337ms/step - loss: 0.1866 - accuracy: 0.9414 - val_loss: 0.1205 - val_accuracy: 0.9613
# Epoch 17/200
# 46/46 [==============================] - 17s 368ms/step - loss: 0.2444 - accuracy: 0.9307 - val_loss: 0.0908 - val_accuracy: 0.9586
# Epoch 18/200
# 46/46 [==============================] - 17s 332ms/step - loss: 0.2061 - accuracy: 0.9395 - val_loss: 0.0929 - val_accuracy: 0.9696
# Epoch 19/200
# 46/46 [==============================] - 17s 336ms/step - loss: 0.1939 - accuracy: 0.9339 - val_loss: 0.1037 - val_accuracy: 0.9586
# Epoch 20/200
# 46/46 [==============================] - 17s 333ms/step - loss: 0.1479 - accuracy: 0.9575 - val_loss: 0.0853 - val_accuracy: 0.9641
# Epoch 21/200
# 46/46 [==============================] - 18s 334ms/step - loss: 0.1795 - accuracy: 0.9369 - val_loss: 0.0748 - val_accuracy: 0.9669
# Epoch 22/200
# 46/46 [==============================] - 17s 331ms/step - loss: 0.1925 - accuracy: 0.9389 - val_loss: 0.1050 - val_accuracy: 0.9613
# Epoch 23/200
# 46/46 [==============================] - 17s 336ms/step - loss: 0.2273 - accuracy: 0.9425 - val_loss: 0.0868 - val_accuracy: 0.9724
# Epoch 24/200
# 46/46 [==============================] - 17s 337ms/step - loss: 0.2431 - accuracy: 0.9353 - val_loss: 0.0809 - val_accuracy: 0.9641
# Epoch 25/200
# 46/46 [==============================] - 17s 331ms/step - loss: 0.2206 - accuracy: 0.9413 - val_loss: 0.0597 - val_accuracy: 0.9751
# Epoch 26/200
# 46/46 [==============================] - 17s 332ms/step - loss: 0.2003 - accuracy: 0.9368 - val_loss: 0.0792 - val_accuracy: 0.9641
# Epoch 27/200
# 46/46 [==============================] - 17s 333ms/step - loss: 0.2125 - accuracy: 0.9373 - val_loss: 0.1075 - val_accuracy: 0.9669
# Epoch 28/200
# 46/46 [==============================] - 19s 339ms/step - loss: 0.1723 - accuracy: 0.9441 - val_loss: 0.0700 - val_accuracy: 0.9779
# Epoch 29/200
# 46/46 [==============================] - 17s 331ms/step - loss: 0.1895 - accuracy: 0.9437 - val_loss: 0.0894 - val_accuracy: 0.9724
# Epoch 30/200
# 46/46 [==============================] - 17s 331ms/step - loss: 0.1588 - accuracy: 0.9551 - val_loss: 0.0832 - val_accuracy: 0.9669
# Epoch 31/200
# 46/46 [==============================] - 18s 328ms/step - loss: 0.1832 - accuracy: 0.9431 - val_loss: 0.0890 - val_accuracy: 0.9613
# Epoch 32/200
# 46/46 [==============================] - 17s 331ms/step - loss: 0.2575 - accuracy: 0.9387 - val_loss: 0.0931 - val_accuracy: 0.9724
# Epoch 33/200
# 46/46 [==============================] - 17s 337ms/step - loss: 0.1927 - accuracy: 0.9589 - val_loss: 0.0921 - val_accuracy: 0.9613
# Epoch 34/200
# 46/46 [==============================] - 17s 328ms/step - loss: 0.1749 - accuracy: 0.9371 - val_loss: 0.0970 - val_accuracy: 0.9613
# Epoch 35/200
# 46/46 [==============================] - 17s 336ms/step - loss: 0.1906 - accuracy: 0.9367 - val_loss: 0.0796 - val_accuracy: 0.9724
# Epoch 36/200
# 46/46 [==============================] - 17s 330ms/step - loss: 0.1846 - accuracy: 0.9444 - val_loss: 0.0821 - val_accuracy: 0.9641
# Epoch 37/200
# 46/46 [==============================] - 17s 333ms/step - loss: 0.1854 - accuracy: 0.9397 - val_loss: 0.0997 - val_accuracy: 0.9669
# Epoch 38/200
# 46/46 [==============================] - 17s 334ms/step - loss: 0.1923 - accuracy: 0.9342 - val_loss: 0.1061 - val_accuracy: 0.9558
# Epoch 39/200
# 46/46 [==============================] - 17s 332ms/step - loss: 0.2610 - accuracy: 0.9391 - val_loss: 0.0852 - val_accuracy: 0.9696
# Epoch 40/200
# 46/46 [==============================] - 17s 334ms/step - loss: 0.1721 - accuracy: 0.9437 - val_loss: 0.1095 - val_accuracy: 0.9586
# Epoch 41/200
# 46/46 [==============================] - 19s 335ms/step - loss: 0.1686 - accuracy: 0.9456 - val_loss: 0.0866 - val_accuracy: 0.9724
# Epoch 42/200
# 46/46 [==============================] - 17s 336ms/step - loss: 0.1792 - accuracy: 0.9434 - val_loss: 0.0850 - val_accuracy: 0.9724
# Epoch 43/200
# 46/46 [==============================] - 17s 335ms/step - loss: 0.1761 - accuracy: 0.9395 - val_loss: 0.0791 - val_accuracy: 0.9696
# Epoch 44/200
# 46/46 [==============================] - 17s 337ms/step - loss: 0.2120 - accuracy: 0.9381 - val_loss: 0.1051 - val_accuracy: 0.9641
# Epoch 45/200
# 46/46 [==============================] - 17s 338ms/step - loss: 0.2153 - accuracy: 0.9483 - val_loss: 0.0862 - val_accuracy: 0.9641
# Epoch 46/200
# 46/46 [==============================] - 17s 331ms/step - loss: 0.1589 - accuracy: 0.9500 - val_loss: 0.0813 - val_accuracy: 0.9724
# Epoch 47/200
# 46/46 [==============================] - 17s 337ms/step - loss: 0.2276 - accuracy: 0.9392 - val_loss: 0.0708 - val_accuracy: 0.9751
# Epoch 48/200
# 46/46 [==============================] - 17s 331ms/step - loss: 0.1997 - accuracy: 0.9417 - val_loss: 0.0856 - val_accuracy: 0.9586
# Epoch 49/200
# 46/46 [==============================] - 18s 329ms/step - loss: 0.1736 - accuracy: 0.9341 - val_loss: 0.0545 - val_accuracy: 0.9751
# Epoch 50/200
# 46/46 [==============================] - 17s 331ms/step - loss: 0.1637 - accuracy: 0.9469 - val_loss: 0.0886 - val_accuracy: 0.9669
# Epoch 51/200
# 46/46 [==============================] - 17s 326ms/step - loss: 0.2326 - accuracy: 0.9395 - val_loss: 0.0953 - val_accuracy: 0.9751
# Epoch 52/200
# 46/46 [==============================] - 17s 343ms/step - loss: 0.1983 - accuracy: 0.9353 - val_loss: 0.0833 - val_accuracy: 0.9724
# Epoch 53/200
# 46/46 [==============================] - 19s 340ms/step - loss: 0.2243 - accuracy: 0.9444 - val_loss: 0.0733 - val_accuracy: 0.9641
# Epoch 54/200
# 46/46 [==============================] - 17s 339ms/step - loss: 0.1592 - accuracy: 0.9448 - val_loss: 0.0879 - val_accuracy: 0.9669
# Epoch 55/200
# 46/46 [==============================] - 17s 365ms/step - loss: 0.1863 - accuracy: 0.9482 - val_loss: 0.0829 - val_accuracy: 0.9724
# Epoch 56/200
# 46/46 [==============================] - 19s 341ms/step - loss: 0.1842 - accuracy: 0.9447 - val_loss: 0.0996 - val_accuracy: 0.9613
# Epoch 57/200
# 46/46 [==============================] - 17s 341ms/step - loss: 0.2427 - accuracy: 0.9308 - val_loss: 0.1107 - val_accuracy: 0.9613
# Epoch 58/200
# 46/46 [==============================] - 17s 343ms/step - loss: 0.1423 - accuracy: 0.9536 - val_loss: 0.1060 - val_accuracy: 0.9586
# Epoch 59/200
# 46/46 [==============================] - 17s 336ms/step - loss: 0.1926 - accuracy: 0.9534 - val_loss: 0.0834 - val_accuracy: 0.9669
# Epoch 60/200
# 46/46 [==============================] - 17s 330ms/step - loss: 0.2614 - accuracy: 0.9216 - val_loss: 0.0592 - val_accuracy: 0.9779
# Epoch 61/200
# 46/46 [==============================] - 19s 337ms/step - loss: 0.1864 - accuracy: 0.9467 - val_loss: 0.0957 - val_accuracy: 0.9669
# Epoch 62/200
# 46/46 [==============================] - 17s 336ms/step - loss: 0.2195 - accuracy: 0.9420 - val_loss: 0.1047 - val_accuracy: 0.9613
# Epoch 63/200
# 46/46 [==============================] - 17s 338ms/step - loss: 0.2665 - accuracy: 0.9286 - val_loss: 0.0929 - val_accuracy: 0.9641
# Epoch 64/200
# 46/46 [==============================] - 17s 340ms/step - loss: 0.1811 - accuracy: 0.9382 - val_loss: 0.0714 - val_accuracy: 0.9724
# Epoch 65/200
# 46/46 [==============================] - 17s 337ms/step - loss: 0.1998 - accuracy: 0.9363 - val_loss: 0.0869 - val_accuracy: 0.9641
# Epoch 66/200
# 46/46 [==============================] - 17s 337ms/step - loss: 0.2033 - accuracy: 0.9562 - val_loss: 0.0997 - val_accuracy: 0.9586
# Epoch 67/200
# 46/46 [==============================] - 17s 342ms/step - loss: 0.2315 - accuracy: 0.9282 - val_loss: 0.0787 - val_accuracy: 0.9696
# Epoch 68/200
# 46/46 [==============================] - 17s 337ms/step - loss: 0.1840 - accuracy: 0.9505 - val_loss: 0.0983 - val_accuracy: 0.9641
# Epoch 69/200
# 46/46 [==============================] - 19s 346ms/step - loss: 0.2185 - accuracy: 0.9433 - val_loss: 0.0975 - val_accuracy: 0.9586
# Epoch 70/200
# 46/46 [==============================] - 17s 340ms/step - loss: 0.1645 - accuracy: 0.9529 - val_loss: 0.0926 - val_accuracy: 0.9751
# Epoch 71/200
# 46/46 [==============================] - 17s 337ms/step - loss: 0.2054 - accuracy: 0.9445 - val_loss: 0.0684 - val_accuracy: 0.9779
# Epoch 72/200
# 46/46 [==============================] - 19s 334ms/step - loss: 0.1918 - accuracy: 0.9468 - val_loss: 0.0794 - val_accuracy: 0.9779
# Epoch 73/200
# 46/46 [==============================] - 19s 332ms/step - loss: 0.1692 - accuracy: 0.9538 - val_loss: 0.0751 - val_accuracy: 0.9696
# Epoch 74/200
# 46/46 [==============================] - 17s 335ms/step - loss: 0.1862 - accuracy: 0.9573 - val_loss: 0.0724 - val_accuracy: 0.9641
# Epoch 75/200
# 46/46 [==============================] - 17s 339ms/step - loss: 0.1889 - accuracy: 0.9517 - val_loss: 0.0574 - val_accuracy: 0.9834
# Epoch 76/200
# 46/46 [==============================] - 17s 339ms/step - loss: 0.2084 - accuracy: 0.9324 - val_loss: 0.0724 - val_accuracy: 0.9724
# Epoch 77/200
# 46/46 [==============================] - 17s 338ms/step - loss: 0.1845 - accuracy: 0.9438 - val_loss: 0.0831 - val_accuracy: 0.9669
# Epoch 78/200
# 46/46 [==============================] - 17s 335ms/step - loss: 0.1898 - accuracy: 0.9466 - val_loss: 0.1011 - val_accuracy: 0.9613
# Epoch 79/200
# 46/46 [==============================] - 19s 338ms/step - loss: 0.2883 - accuracy: 0.9390 - val_loss: 0.0766 - val_accuracy: 0.9696
# Epoch 80/200
# 46/46 [==============================] - 17s 345ms/step - loss: 0.2301 - accuracy: 0.9338 - val_loss: 0.1076 - val_accuracy: 0.9669
# Epoch 81/200
# 46/46 [==============================] - 17s 340ms/step - loss: 0.2208 - accuracy: 0.9460 - val_loss: 0.1151 - val_accuracy: 0.9558
# Epoch 82/200
# 46/46 [==============================] - 17s 341ms/step - loss: 0.1873 - accuracy: 0.9522 - val_loss: 0.0931 - val_accuracy: 0.9696
# Epoch 83/200
# 46/46 [==============================] - 17s 335ms/step - loss: 0.3005 - accuracy: 0.9419 - val_loss: 0.1152 - val_accuracy: 0.9641
# Epoch 84/200
# 46/46 [==============================] - 17s 339ms/step - loss: 0.1463 - accuracy: 0.9563 - val_loss: 0.1129 - val_accuracy: 0.9641
# Epoch 85/200
# 46/46 [==============================] - 17s 332ms/step - loss: 0.2323 - accuracy: 0.9439 - val_loss: 0.0734 - val_accuracy: 0.9613
# Epoch 86/200
# 46/46 [==============================] - 19s 332ms/step - loss: 0.1816 - accuracy: 0.9434 - val_loss: 0.0909 - val_accuracy: 0.9724
# Epoch 87/200
# 46/46 [==============================] - 17s 364ms/step - loss: 0.2035 - accuracy: 0.9444 - val_loss: 0.0961 - val_accuracy: 0.9641
# Epoch 88/200
# 46/46 [==============================] - 17s 340ms/step - loss: 0.1926 - accuracy: 0.9498 - val_loss: 0.0750 - val_accuracy: 0.9724
# Epoch 89/200
# 46/46 [==============================] - 17s 335ms/step - loss: 0.1889 - accuracy: 0.9446 - val_loss: 0.0773 - val_accuracy: 0.9641

# %%
model.save('ResNet_10%_v2.h5')

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
dir = '/content/drive/My Drive/2020 - Quinto Anio/TESIS_Eugenia_Berrino/DS_comp_nodef'
test_datagen = ImageDataGenerator(rescale = 1./255)#Rescaling(1./255, input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)))
test_batches = test_datagen.flow_from_dataframe(
    df_test, 
    directory=dir,
    x_col='ImageID',y_col='Projection',
    target_size=IMAGE_SIZE,
    shuffle=False,
    batch_size=1,
    seed=42,
    class_mode="categorical"#, validate_filenames=False
    )
# Out:
# Found 4360 validated image filenames belonging to 3 classes.

# %%
model = load_model('ResNet_10%_v2.h5')

# %%
#Calculamos la matriz de predicciones
result_test=model.predict(test_batches, verbose=1)
print(result_test.shape)
# Out:
# 4360/4360 [==============================] - 41s 9ms/step
# (4360, 3)

# %%
#Calculamos la matriz de predicciones
#result_test=model.predict(test_batches, verbose=1)
print ("Loss = " + str(result_test[0]))
print ("Test Accuracy = " + str(result_test[1]))
# Out:
# Loss = [1.9459033e-06 1.7856976e-07 9.9999785e-01]
# Test Accuracy = [1.8997946e-10 1.3508073e-06 9.9999869e-01]

# %%
#Obtenemos el nombre de clase asociado a cada indice
classes_dict = dict(zip(test_batches.class_indices.values(),test_batches.class_indices.keys()))
classes_dict
# Out:
# {0: 'AP_horizontal', 1: 'L', 2: 'PA'}

# %%
#Obtenemos el índice de mayor score en cada fila (cada imagen)
preds = result_test.argmax(axis=-1)

# %%
#Obtenemos el nombre de clase asignado a cada clase
preds_classes = [classes_dict[p] for p in preds]

# %%
# A qué clase asigna cada imagen
preds_classes

# %%
#Evaluar cuantas predicciones hay de cada clase
pd.Series(preds_classes).value_counts()
# Out:
# PA               2797
# L                1451
# AP_horizontal     112
# dtype: int64

# %%
import numpy as np
#Obtenemos el nombre de clase de la etiqueta verdadera (groun-truths)
gts = np.array([classes_dict[p] for p in test_batches.classes])

# %%
#Evaluamos métricas de clasificación
from sklearn.metrics import classification_report, confusion_matrix

print(classification_report(gts,preds_classes))
# Out:
#                precision    recall  f1-score   support
#
# AP_horizontal       0.90      0.47      0.61       217
#             L       0.97      0.98      0.97      1427
#            PA       0.96      0.99      0.97      2716
#
#      accuracy                           0.96      4360
#     macro avg       0.94      0.81      0.85      4360
#  weighted avg       0.96      0.96      0.96      4360

# %%
def plot_confusion_matrix(cm, classes,
                          title='Matriz de confusión',
                          cmap=plt.cm.Blues):
    plt.figure(figsize=(8,8))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, fontsize=20)
    plt.yticks(tick_marks, classes, fontsize=20)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center", fontsize=20,
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('Etiqueta verdadera', fontsize=20)
    plt.xlabel('Predicción del modelo', fontsize=20)
    plt.show()

# %%
confusionMatrix = confusion_matrix(gts,preds_classes)

plot_confusion_matrix(confusionMatrix,test_batches.class_indices.keys())

# %% [markdown]
# En este caso, podemos ver que el modelo no aprendió, se limitó a clasificar a todas las imágenes como pertenecientes a una sola clase.

# %% [markdown]
# # Curvas AUC ROC y Precision Recall

# %%
import numpy as np
from scipy import interp
import matplotlib.pyplot as plt
from itertools import cycle
from sklearn.metrics import roc_curve, auc

# %%
y_test = pd.get_dummies(gts).to_numpy()

# %%
y_score = result_test
# Plot linewidth.
lw = 2

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(NUM_CLASSES):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Compute macro-average ROC curve and ROC area

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(NUM_CLASSES)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(NUM_CLASSES):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= NUM_CLASSES

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure(1)
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(NUM_CLASSES), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Some extension of Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")
plt.show()


# Zoom in view of the upper left corner.
plt.figure(2)
plt.xlim(0, 0.2)
plt.ylim(0.8, 1)
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(NUM_CLASSES), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Some extension of Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead

# %%
Y_test = pd.get_dummies(gts).to_numpy()
y_score = result_test

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score

# For each class
precision = dict()
recall = dict()
average_precision = dict()
for i in range(NUM_CLASSES):
    precision[i], recall[i], _ = precision_recall_curve(Y_test[:, i],
                                                        y_score[:, i])
    average_precision[i] = average_precision_score(Y_test[:, i], y_score[:, i])


# A "micro-average": quantifying score on all classes jointly
precision["micro"], recall["micro"], _ = precision_recall_curve(Y_test.ravel(),
    y_score.ravel())
average_precision["micro"] = average_precision_score(Y_test, y_score,
                                                     average="micro")
print('Average precision score, micro-averaged over all classes: {0:0.2f}'
      .format(average_precision["micro"]))
# Out:
# Average precision score, micro-averaged over all classes: 0.99

# %%
plt.figure()
plt.step(recall['micro'], precision['micro'], where='post')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title(
    'Average precision score, micro-averaged over all classes: AP={0:0.2f}'
    .format(average_precision["micro"]))
# Out:
# Text(0.5, 1.0, 'Average precision score, micro-averaged over all classes: AP=0.99')

# %%
from itertools import cycle
# setup plot details
colors = cycle(['navy', 'turquoise', 'darkorange', 'cornflowerblue', 'teal'])

plt.figure(figsize=(7, 8))
f_scores = np.linspace(0.2, 0.8, num=4)
lines = []
labels = []
for f_score in f_scores:
    x = np.linspace(0.01, 1)
    y = f_score * x / (2 * x - f_score)
    l, = plt.plot(x[y >= 0], y[y >= 0], color='gray', alpha=0.2)
    plt.annotate('f1={0:0.1f}'.format(f_score), xy=(0.9, y[45] + 0.02))

lines.append(l)
labels.append('iso-f1 curves')
l, = plt.plot(recall["micro"], precision["micro"], color='gold', lw=2)
lines.append(l)
labels.append('micro-average Precision-recall (area = {0:0.2f})'
              ''.format(average_precision["micro"]))

for i, color in zip(range(NUM_CLASSES), colors):
    l, = plt.plot(recall[i], precision[i], color=color, lw=2)
    lines.append(l)
    labels.append('Precision-recall for class {0} (area = {1:0.2f})'
                  ''.format(i, average_precision[i]))

fig = plt.gcf()
fig.subplots_adjust(bottom=0.25)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Extension of Precision-Recall curve to multi-class')
plt.legend(lines, labels, loc=(0, -.38), prop=dict(size=14))


plt.show()
