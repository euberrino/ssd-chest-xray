# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
imgs_train = pd.read_csv('/content/drive/MyDrive/2020_Quinto_Anio/TESIS_Eugenia_Berrino/Part_II_DS/vinbigdata/imgs_train.csv')
imgs_valid = pd.read_csv('/content/drive/MyDrive/2020_Quinto_Anio/TESIS_Eugenia_Berrino/Part_II_DS/vinbigdata/imgs_valid.csv')
imgs_test = pd.read_csv('/content/drive/MyDrive/2020_Quinto_Anio/TESIS_Eugenia_Berrino/Part_II_DS/vinbigdata/imgs_test.csv')
imgs_train
# Out:
#       Unnamed: 0                          image_id
# 0              0  a8dd1496dde8d6f63316c8ec2a823b38
# 1              1  4eed7a6bb03888eade13343f141dd5c8
# 2              2  a0a6050fdda9f59eff1ca6a197883fcb
# 3              3  c42b5e8105ed48a96bf7273e25f2a047
# 4              4  d700828f067b24ac9bc70bc8bbee1bea
# ...          ...                               ...
# 1290        1290  ee9e445e316c60e028de2486e3f459df
# 1291        1291  43e96bafa84091eec856901f949efa05
# 1292        1292  0453de2faeb8d349af739a68d9dee1cb
# 1293        1293  1c1ef26e3b3323f74041f6dd2371cd24
# 1294        1294  ee47fd39217a0d25550cb6b9badd3ee2
#
# [1295 rows x 2 columns]

# %%
df_cons = pd.read_excel('/content/drive/MyDrive/2020_Quinto_Anio/TESIS_Eugenia_Berrino/Part_II_DS/vinbigdata/consolidations_split.xlsx')
df_cons
# Out:
#       Unnamed: 0  Unnamed: 0.1  ...      area  Group
# 0              0             7  ...  0.001809  Valid
# 1              1            10  ...  0.006522  Valid
# 2              2            17  ...  0.214912  Train
# 3              3            36  ...  0.008788  Train
# 4              4            40  ...  0.000323  Train
# ...          ...           ...  ...       ...    ...
# 5893        5893         67863  ...  0.004555  Train
# 5894        5894         67889  ...  0.007415  Train
# 5895        5895         67890  ...  0.026542  Train
# 5896        5896         67891  ...  0.014040  Train
# 5897        5897         67893  ...  0.002670  Train
#
# [5898 rows x 18 columns]

# %%
def create_labels(type):
  if(type=='valid'):
    df = imgs_valid
  elif (type =='train'):
    df = imgs_train
  elif(type=='test'):
    df = imgs_test
  label_dir =  '/content/drive/MyDrive/2020_Quinto_Anio/TESIS_Eugenia_Berrino/Part_II_DS/labels_mine/' + str(type)
  for image in df['image_id']:
    my_list = []
    for index, row in df_cons.iterrows():
      if(image == row['image_id']):
       if(row['class_name']=='Consolidation') 
       my_list.append('0' + '\t' + str(row['x_mid']) + '\t' + str(row['y_mid']) + '\t' + str(row['w']) + '\t' + str(row['h']) + '\n')
    filename = image.split('.')[0]
    file1 = open(os.path.join(label_dir, filename+'.txt'),"w") 
    file1.writelines(my_list) 
    file1.close()

# %%
create_labels('train')

# %%
create_labels('valid')

# %%
create_labels('test')
