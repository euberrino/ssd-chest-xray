# %% [markdown]
# # Brief Explanation
#
# The aim of this notebook is to generate a binary metric in order to evaluate my object detection model just in terms of its classification task ("Lung Opacity"- "No finding")
#
# The first step is to define a new test set. Our previous one included just 278 images, due to a lack of more "Lung Opacity" images. As this is a test set, and there are plenty images belonging to the "No finding" group in the original dataset that haven't been used, the new one will contain a 80% - 20% ("No finding" - "Lung Oppacity" ) proportion

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install bbox-visualizer
import bbox_visualizer as bbv
import numpy as np
import pandas as pd
import os
from glob import glob # Retrieve files/pathnames matching a specified pattern
import shutil, os #operations on files, operating system dependent functionality

import matplotlib.pyplot as plt
import seaborn as sns
#import bbox_visualizer as bbv

from sklearn.model_selection import GroupKFold
from tqdm.notebook import tqdm #Progress bar

import cv2
from skimage.io import imread
from sklearn.model_selection import train_test_split
# Out:
# Collecting bbox-visualizer
#   Downloading https://files.pythonhosted.org/packages/e2/ed/3fee03fcc9913a772a802e9407a49dfb026f78bab4f1385e8b91eb544e4a/bbox_visualizer-0.1.0-py2.py3-none-any.whl
# Installing collected packages: bbox-visualizer
# Successfully installed bbox-visualizer-0.1.0

# %%
fds_ws = pd.read_excel('/content/drive/MyDrive/Quinto_Anio/TESIS_Eugenia_Berrino/Part_II_DS/vinbigdata/fds_withsplit.xlsx')
original_test = fds_ws[fds_ws['Group']=='Test']
original_test.head()
# Out:
#     Unnamed: 0  Unnamed: 0.1  ... height Group
# 5            5         32939  ...   2880  Test
# 15          15         59353  ...   2930  Test
# 16          16         43678  ...   2880  Test
# 26          26         22204  ...   3174  Test
# 36          36          6575  ...   2273  Test
#
# [5 rows x 13 columns]

# %%
original_test.class_name.value_counts()
# Out:
# Consolidation    849
# No finding        14
# Name: class_name, dtype: int64

# %%
original_test = original_test.drop(columns=['Unnamed: 0.1','Group'])
original_test.columns
# Out:
# Index(['Unnamed: 0', 'image_id', 'class_name', 'class_id', 'rad_id', 'x_min',
#        'y_min', 'x_max', 'y_max', 'width', 'height'],
#       dtype='object')

# %%
ds = pd.read_excel('/content/drive/MyDrive/Quinto_Anio/TESIS_Eugenia_Berrino/Part_II_DS/vinbigdata/My_DS.xlsx')
ds
# Out:
#       Unnamed: 0                          image_id  ... width  height
# 0          57877  7b30d37b73be405bfd91ed5e2d46c473  ...  2304    2880
# 1           4860  7acb16c6d6f5cfc41a958e0b41e25106  ...  2304    2880
# 2          25382  6c79f2551808438721052023e043ab4d  ...  3072    3072
# 3          61581  ecf474d5d4f65d7a3e23370a68b8c6a0  ...  2408    2692
# 4          12091  4b001bab36d94f73c1ead3ab74690dbc  ...  1936    2488
# ...          ...                               ...  ...   ...     ...
# 5986       22141  8cb084ad48ad4a21e15bdb8f4567ed8f  ...  2466    2347
# 5987       27395  ec6ec12533b8495bb7344d8895dd4f05  ...  2304    2880
# 5988       28828  5d6c0df203f0e3f04467e27507029026  ...  2851    2967
# 5989       25185  0b98b21145a9425bf3eeea4b0de425e7  ...  2208    2688
# 5990       52186  1812172c7ad3771c05d1238bb3066217  ...  2564    2564
#
# [5991 rows x 11 columns]

# %%
fds =  ds[~ds['image_id'].isin(original_test['image_id'])]
len(fds)
# Out:
# 5128

# %%
nof = fds[fds['class_name']=='No finding']
print(nof.head())
print(len(nof))
# Out:
#       Unnamed: 0                          image_id  class_name  ...   w   h  area
# 4046       35643  2e968b23fc1bc1150bf1943e1b53b031  No finding  ... NaN NaN   NaN
# 2747       38968  32557c0fb41d37a9e3c8485d3dcdb8cc  No finding  ... NaN NaN   NaN
# 664        23788  9d82b2a79a46c1a91802cad4043cc36d  No finding  ... NaN NaN   NaN
# 5638       53868  f4b4ec6b571cc34532856f68890a89b1  No finding  ... NaN NaN   NaN
# 193        57501  50742e2516c5af7abede56edbd3bb6bb  No finding  ... NaN NaN   NaN
#
# [5 rows x 16 columns]
# 158

# %%
fds = pd.concat([fds,nof]).sample(frac=1)
fds.head()
# Out:
#       Unnamed: 0                          image_id  ... width  height
# 5925        3845  997fca43b97287e53c551c3d4753edcb  ...  2048    2500
# 2502       32411  60398630bcbf4f2fa6f5730fd9a9f4dc  ...  3072    3072
# 5084       10874  05721adb43ab7c061733568b274c006b  ...  2304    2880
# 2218       49176  f5f8866773cc80861a7f5c30502d0fbb  ...  2304    2880
# 3969       53656  a6bcb9f5d59588d699c5aa83cd3039c7  ...  2540    3072
#
# [5 rows x 11 columns]

# %%
fds.class_name.value_counts()
# Out:
# Consolidation    5049
# No finding        158
# Name: class_name, dtype: int64

# %%
# Normalizing Annotations 

# BB Normalized Limits
fds['x_min'] = fds.apply(lambda row: (row.x_min)/row.width, axis =1)
fds['y_min'] = fds.apply(lambda row: (row.y_min)/row.height, axis =1)

fds['x_max'] = fds.apply(lambda row: (row.x_max)/row.width, axis =1)
fds['y_max'] = fds.apply(lambda row: (row.y_max)/row.height, axis =1)

# BB Normalized Center
fds['x_mid'] = fds.apply(lambda row: (row.x_max+row.x_min)/2, axis =1)
fds['y_mid'] = fds.apply(lambda row: (row.y_max+row.y_min)/2, axis =1)

# BB Nomalized With & Height
fds['w'] = fds.apply(lambda row: (row.x_max-row.x_min), axis =1)
fds['h'] = fds.apply(lambda row: (row.y_max-row.y_min), axis =1)

# BB as a % area of the image
fds['area'] = fds['w']*fds['h']
fds.head()
# Out:
#       Unnamed: 0                          image_id  ...         h      area
# 5925        3845  997fca43b97287e53c551c3d4753edcb  ...  0.033600  0.001099
# 2502       32411  60398630bcbf4f2fa6f5730fd9a9f4dc  ...  0.144857  0.020229
# 5084       10874  05721adb43ab7c061733568b274c006b  ...  0.029167  0.001013
# 2218       49176  f5f8866773cc80861a7f5c30502d0fbb  ...  0.141319  0.017358
# 3969       53656  a6bcb9f5d59588d699c5aa83cd3039c7  ...  0.025065  0.000681
#
# [5 rows x 16 columns]

# %%
unique = fds.drop_duplicates(subset = ["image_id"])
unique
# Out:
#       Unnamed: 0                          image_id  ...         h      area
# 5925        3845  997fca43b97287e53c551c3d4753edcb  ...  0.033600  0.001099
# 2502       32411  60398630bcbf4f2fa6f5730fd9a9f4dc  ...  0.144857  0.020229
# 5084       10874  05721adb43ab7c061733568b274c006b  ...  0.029167  0.001013
# 2218       49176  f5f8866773cc80861a7f5c30502d0fbb  ...  0.141319  0.017358
# 3969       53656  a6bcb9f5d59588d699c5aa83cd3039c7  ...  0.025065  0.000681
# ...          ...                               ...  ...       ...       ...
# 5852       41084  088d83359d1a00ba24251220ace42edc  ...  0.039358  0.002609
# 977        53296  a61be8051f02ec494ed40696e988f6d1  ...  0.041319  0.002044
# 2642        6515  d571f85ab9434bcb8bc11bd175453c96  ...  0.134440  0.010206
# 252        61956  d79068eb77a5aa51eb57904fbfce1720  ...  0.067361  0.015963
# 2698       37663  9c9f556eea533f066368e0f4a452bee7  ...  0.160886  0.016960
#
# [1652 rows x 16 columns]

# %%
unique = unique[['image_id','class_name']]
unique.class_name.value_counts()
# Out:
# Consolidation    1573
# No finding         79
# Name: class_name, dtype: int64

# %%
imgs_test = pd.read_csv('/content/drive/MyDrive/Quinto_Anio/TESIS_Eugenia_Berrino/Part_II_DS/vinbigdata/ctest.csv')
imgs_test
# Out:
#      Unnamed: 0                          image_id
# 0             0  21cf533a9fe77bdbee21babd427a0d1f
# 1             1  bc2be005526db7ab9d5ec6741ddee945
# 2             2  79c5d4d7f3b2e7a5a183bfbe664c699d
# 3             3  c34e6aa7a5db3386850b830dd3c45a98
# 4             4  c24029f31fb9ae265934082ce6b47d33
# ..          ...                               ...
# 273         273  071ff9c782ead87dfa9b1c025c25e769
# 274         274  1bbd7232924e951e7fa87ffa0f62ec3d
# 275         275  f58ecf974a05d2f5ece85aa9393cf9d6
# 276         276  7978725e43f1b301551e0fdbc32faef5
# 277         277  c4d68aad9fdec87b76853d26744026bb
#
# [278 rows x 2 columns]

# %%
tests = np.concatenate((nof.image_id.to_numpy(),imgs_test.image_id.to_numpy()))
tests
# Out:
# array(['910e6bb0acb1c0b9156b4b7ae0dc752c',
#        '91783a3a0b479febd50ea952f711d776',
#        '50742e2516c5af7abede56edbd3bb6bb',
#        'bee99c179da019550328e64a55713d5e',
#        '524f09c24a034a2daae14151142ff9be',
#        'cfbb4effef1cb2fe0311d38e3d35b5ea',
#        '3212a84727e182171bd4ab3da7d560a5',
#        '758ecebbb7d3da26eeadc428aafc991b',
#        'daa9fa42d787183c91519315f5927cce',
#        '5b65be064e0cee0795a5c98148360b63',
#        '9d82b2a79a46c1a91802cad4043cc36d',
#        'b7c2310d1b1f98c1bb88789595d78613',
#        '52a8241a351307b812b63dd80912e0dd',
#        'fe095046c8e69bfe5d169425c73b3135',
#        '78d5ff1cb48bc317bd20d7e3ddae34f5',
#        'b2c002bcee4f53855b238c491956f953',
#        '799915888fe8902eddfe9a19627c618c',
#        'fe17eb35352cbd7bbe33d90206276c44',
#        'aff94c85d299cc26f549b22be3c54d16',
#        '51c9555c13a2ce6554d4592c95b80a39',
#        'e1a603beea2b53b3031a337d8a87cd72',
#        '67f6b4a6c560951eef3128e2e71419c7',
#        '5dcadceca5d9be91e3a484b004989a11',
#        'baa01cd2f8ef7a1c64aa9b9861796cd0',
#        '92ea5983fa054b5ca1f6bf98971f61af',
#        '648f133ac0f1120858a5ec22d9931a7d',
#        '6bcaa8ca1344287b61e15b3e8cffcaf2',
#        '5e26f541d9d73c26f205d2406ea54a1e',
#        'd5b83f7e5dd6954c3e5613d1e7792e1e',
#        '7e2debe4301fb5848fe57fb2f8ada4d8',
#        'fcc781b652368c74e8e59d46fb4a76af',
#        'f89632e332083923eaf2a5efc84ad5e6',
#        '6c558f18039960a5fe500dd93c2ba6b9',
#        '4aacc762e618db842250314e94272db8',
#        'b4e8d947847f7026e046ccc3ea68fb6d',
#        '0c373b6fd7836eb3f31de84e6d0082c9',
#        'b3f669836a20bb2a8ce9ad0a90e49d5c',
#        'ecbacb5e591dfa3ed48c414221c813c7',
#        '32557c0fb41d37a9e3c8485d3dcdb8cc',
#        '0740dd59179b3143d02c3a477aa65894',
#        '18b496f16e2941e5f8e0f7db81d3098e',
#        'c0abae25111ef8ad27092268ee020363',
#        '1406af2d31790c267b8b17d301ff1ab3',
#        '1fb52c6de89983f8e92e0d3512da68a0',
#        '11b45b85ec598039c5b2da0ebc23d0a3',
#        '9b7187b3675320c75ec43edd333ef2fc',
#        '53604ac3eb90b1d1f1e48c432088e240',
#        'c9e5a7d70ab7f51f7183827c277dc3ac',
#        'b7cbff9ceb2ee43fc694961c647cfa77',
#        'e51f4e56fc5e970b796959961c10ce26',
#        '21ae8b5e6e2a0647a7bb648c15241feb',
#        '1aae727ec5c427a7af7b9d3f9dbfb09c',
#        'a3c6774d824247bdd27105927abed76b',
#        '2e968b23fc1bc1150bf1943e1b53b031',
#        '388f466e82d76282997f1552eb1f5e02',
#        'ca93731624a1b60fcb2c0bcf1f2d0a8a',
#        '803c1790b27119f7a38f2959198392cf',
#        '37345611042805f08784200375e7f36c',
#        '3303206b4b2cb0c6da37a0a3e9d23a86',
#        '5c6ac21d8e2a8892a2685c23f393a2d9',
#        '5f009092caee3729873a324a96749949',
#        '0fdba5b4298773f488709251e49b26a2',
#        '3e40696236bdb6dec60938d7f7d8aa2b',
#        'e09fa966992325c6e86d7727cfc53ca9',
#        '285eb72532207394c338cb6c08bc954c',
#        'd722400ab7c39334ff3d43316f6b4ff6',
#        '8c4a869068e1f748cf808d15d63f2f7c',
#        '3abdf429daeb55e510e29a698977c217',
#        '3043d7e62e74203cfc8704d7dae08fc3',
#        'c48286c8df6f70869101a493d1e84c39',
#        '5376ff68b27e97b653b521a5470b7fdd',
#        '87c3cdf9d5dab832b01f2c94321e3130',
#        'e65244f755c20b6c3925fb3669c24b0b',
#        'f4b4ec6b571cc34532856f68890a89b1',
#        '0c9349523719ed8208d219a3eb386021',
#        '0abc9663ba5cfb779dbc26960dbc5b81',
#        '162b6f2f6f04c9ab806583092dfadc13',
#        'f0591ae18efc36ec22302f52a8ad7667',
#        'fe67a20679c1eed6e19ee55f776d0f6d',
#        '21cf533a9fe77bdbee21babd427a0d1f',
#        'bc2be005526db7ab9d5ec6741ddee945',
#        '79c5d4d7f3b2e7a5a183bfbe664c699d',
#        'c34e6aa7a5db3386850b830dd3c45a98',
#        'c24029f31fb9ae265934082ce6b47d33',
#        'd16b67fee07971da41a3d08707ccd864',
#        '7b759182d86f6a44b377ffcfce8a3b53',
#        '4e39db9ee3a3fa04e219e4649581708a',
#        '381e9c224c892d437f498779e349469e',
#        '91a12fbbe1ad5eb62cdf97edeb122280',
#        'ebf4ffbcf6de699bf9deab70f0dee8ff',
#        'cdbd07a6e9e17958d4cafd4278872806',
#        '230ffa646a0bec6bce8b027cd4c66832',
#        '2a2d24f9e9397ea669cf6ec9f850c367',
#        '17791317b59d89c03ce7a15826e1b876',
#        '5766dfc49e91557e8cd4a06a406b8890',
#        'a692a1afd469e83448d1148facc77de7',
#        '5450f21b06e8ee3fcdc1375711bc28ee',
#        '454d4b20bb55eb38f90fd51706531b9e',
#        '639a44bdf6f3cfe5d05f96683604e758',
#        'eca27ff9495044fbcd347ee51a8f1187',
#        'f1d1e5089e66fc256f08e621b5dcc9bf',
#        '1e584da1fcf0c0297a22f0e36ce86732',
#        '30303a4b9ba969bea4e676cbd4a2496c',
#        '513203e29fe43941076e37a945e58c36',
#        '07d004fabfd7246f9ed4283dd5237deb',
#        'fa9cd1a78a6d2d8d6e918a8c4125faf4',
#        'c9e29220b5d0f9cfdb250f0872648a89',
#        '3c58145fc5651bd028aaee3d5f3d6c40',
#        '2bac12b65fe143e0d0a4b56b320782e8',
#        'f7cca0874f0a8fdfdcb8952ec15c2e24',
#        'd7bbb290f6691900ee45ea1ed1d5787f',
#        '8fe0e719bc142d9327cb86cc28e82b03',
#        'b3588a07ee672507c31f69109089b805',
#        'b2a52a18d74c641353762a0c1569a695',
#        '6e4915e84e38de5d90efe0ecfd8f2cf6',
#        '305e4add9c72c91e9984305bf4e85aee',
#        '7253800842122c9e6e95878b46008f54',
#        'bdde108a7d024a734cdbed2952f64fe1',
#        '623a14228a9ea0c33a9012c02ef70487',
#        '00f2f97f74e086e1f82acc285ee4a5c5',
#        '1e942d9666eb7b3cd0bf4e2bedae5fd6',
#        'bc87c2265556912b25d36f2fef105a01',
#        '14fbd0bf63f33188f29e54275fb7cafb',
#        'a6541e2d7a4e09d6c1bdee83632bf781',
#        'b720e511bfdfb393b77a26c29fc8cd91',
#        'e7af557ff6a1782400710d2c8ddb2568',
#        '2e62a91d3bdb8e212af2518125eb9dbc',
#        'ba0f97b49906ccf1bf205dd7ca108c06',
#        '00150343289f317a0ad5629d5b7d9ef9',
#        '2d377f5b2bd10b8ead268046859d939a',
#        '78b96ab5b7fc1d75d73b3c9c747d5c96',
#        '62fad4135a04319bc5e499828b05ac70',
#        '3aefb8dc3f0615131c0dc1477b4e3133',
#        '2fdd72337c9a875cf679564355b4bef2',
#        '3115c1b6368f91b45f691edbd63f1a78',
#        '69972b49aac9f4aea137e51984cf8691',
#        '2866813d0d8eeae54af11160adb68731',
#        '3a6264c66e1ccad3f67960d50a152708',
#        '0005e8e3701dfb1dd93d53e2ff537b6e',
#        '8098d1ce056318c03a3c70ccf3707945',
#        'c04ee933a8fed37ebbeb697b03356a56',
#        '1831b088f3a62617cb5cacc3d852cd3c',
#        'df2e21b90ce0510ed66e161136cf60ad',
#        'a07064273b3f1112655970e8326f25df',
#        '604340ab6423f81a91ac72182163e9a4',
#        '906a43ceed5a95c81a94cc7c6ea41027',
#        '662fe30af3399b56c1579e95b0c6c87e',
#        'd60fdd6237c71b741d10c85895723d16',
#        '15c3fc505c414c69ba757cb3be3ed213',
#        'daa2bf07bac956d6742ac7fda965cf99',
#        '735023a2b17a5222636abc2784772804',
#        'f244d8f6b541d370470f56b8f6ebcb3b',
#        '0690821a2e255ce175bfa7f36e308f63',
#        '4268985caaa0bb4145dd056d5aa84b27',
#        'c2d4ab1622ab34e5680710a63501c8b6',
#        '65ad4fb69f36c807fce87e66a1c6533d',
#        '529d855ec524ddf484434d90da0e3f4a',
#        'd3637a1935a905b3c326af31389cb846',
#        '21d5465ffc737f2c94f66cc5b740614e',
#        'e4fe775718f2633a8989f20e06612f01',
#        'bc87ef332a3c532a7e86893cae30e127',
#        '63f24af3bd9f735911958c1190306af1',
#        '025534801b62d61f1c1c9e571ea74695',
#        'da648f4e3bf110e8c31b0fd1859c19c2',
#        '7ffe83778375bb8229b12c2ad4570c0e',
#        '343e1bdfaa62eb9f0148e3cd32aab124',
#        'd1ae8f8c681cf7e9ad6fc1f8ab02dc3a',
#        'b775ef55984de7ff2b12941010f9d968',
#        'c5a45ede0cbd270bf54e8a5e7fd27813',
#        'ca6c1531a83f8ee89916ed934f8d4847',
#        'c39440999e8b3e376911ab851a7c56f6',
#        '2b5284b043c6459e1e1e0a4a328cad79',
#        '2c8f7823a733497e98add3125db370cf',
#        '613fd7f3a8b48248d4027c90a414ff9a',
#        '92e79511cf61feac9fb92f92325c0a19',
#        '813e13e8b9385cbcffc45356265f6a10',
#        '725d3455da58a90c17e5eba4b4520e97',
#        '980cbaa4ca9127c95c7a24cfa7b08598',
#        'f4c12a07224893104dec25b926db33a1',
#        '7d3e79d32d233140b7e30880739a42c4',
#        '3ffaeb3a9eb495e0a59bd62b09bdf319',
#        '5c236bd87dff8c15d259c70b842620aa',
#        'b154780d4c3de6dfedeb1efcb2411575',
#        'af201da8a5f8354c4c3291995d5cbafd',
#        'c1c9528727dd016bad131ff8c3863774',
#        '6137da0107d18f2bc35b6814c0f00ac8',
#        'fb986f9e81efde615e0364b35efdb377',
#        'f9e722d2706d42998afff41568223a01',
#        '4127fa1e8bcb9931cc8b49367eecef78',
#        '9a321e5a866cee9e943cf5f3684de512',
#        'fd810298e165ef0b9a88bb25fda7a34b',
#        '4869a847a5271f2eeffe65ff1db8a9b1',
#        '7db70125d7739e6cd0c442e7b7592d4c',
#        '90823fdce55e57a5c6de680ccf9ffc38',
#        'fe48b59fe20a779d3a6a32d7a22e4b8b',
#        '764eeaca1e91f7410e68f3daf40de6ab',
#        '776d1803d568d646b2e8d8b0648cde5a',
#        'f4da0959856bcdd4b91e0c6949b109e3',
#        '6c07e9a9fc06aa20e54a83cded97aa7a',
#        '0a14aeaf02d42990d8bb5d55270b7274',
#        '3312ab0661750f9899b4589eae97731a',
#        'eaa5aa491942a0bbc9a161ed3f08c2b5',
#        '91c5f8decf441bfaf7c89e7c3dd06fd9',
#        'ac1d94eefdeeb76ee96e56b8856f7209',
#        '80bc61a643d289b3c2afc3a1ad297e48',
#        '66c03db83615b5c925b5bbdcd4a3c326',
#        '2596fb668f0ec31ac6622ea546e600cf',
#        '09175449df9374e0f6afe517f7b6249f',
#        'c32573547f924b6b663798730d915724',
#        'cdeda235172891a9886537799cd57d76',
#        '52a4ee5944586edccdb0e1f25b7a9ef8',
#        'fbfa7706ae60ef2f3f18211269a8d2ac',
#        'b42962e103033ae66afb049d00cb477c',
#        'bd3fe876153eeddad8bab49b129ea081',
#        '8c09865ee3cb674cc41dee8bca45fe5a',
#        '18ee9ef3baea468de2087e0edd85e919',
#        '85e95b13040ae3e20eccac186b93e6ac',
#        '53e2a10eb9969b0e336a51d11dda17f9',
#        'ccce794d56a43641c1bb3d6b0253e794',
#        '8acab997bea043eb15c9aa293b095374',
#        '0c577dc6594dab44ebbd6964de673eaa',
#        '78faf91d607511da380a6cc4f0a335d1',
#        '9071e5009f5db86b4c0dd0f6280b2c7a',
#        '633440744a1f7413483909dc0af84de1',
#        'b76cca59757045fa3cedad238c878354',
#        '4a2dec8f7163be64ef67f0d09056c921',
#        '2d6c36cb32352b891ef90fb11f3215f7',
#        '305c85dddfdddac905f288a8106ca371',
#        'efc7bc78ce88e95191fdab525f974c24',
#        '26d1d5a0ef2e692c6340e74859ffdc53',
#        'ad21e3f856bd69daf2ee8b6699bd32cf',
#        '1dafb16f8c69e188cf2152200e0cb2ef',
#        'c18362ca7e7d5df7a4dd8db31dfed194',
#        '697c98dcc1457ad774db7b42a4e1e8b4',
#        'a5e985887d6db5408eeac67bcdf771c6',
#        '035480fbf46e946e21e7dce78637c329',
#        'eacc53e9f724bd51a38d76306e6db8d2',
#        '395a89a6041167d0254dc826ddfe7110',
#        'c3abe21f7e07452e6760cdc2cab95296',
#        '0b1b897b1e1e170f1b5fd7aeff553afa',
#        '1066a058b5bae597f2dbb33780c2577d',
#        '02562eb68a9c682f5f644fa7a099733f',
#        '714e4c788c40892e9a5500e4fde9c753',
#        '3ee8d416f1b67797ce0495b4393b2aaf',
#        '58f1092e67574175f2f17b06b1f66911',
#        'be95363066a0f6e2d9644cc14b39d3e1',
#        'fdd529400be877bedaf4f2df9176cedf',
#        '7d24c1ef5bcdd03fc1b01c8e6086c9d1',
#        'e5a6825407439b31e234e69989ccd542',
#        '2254df0c59c659c6eec67a73327bc857',
#        'cf95785b8e8bf924e9cf0b51faef41aa',
#        '440d5de43270006800efa1caecede2f1',
#        'a6b6e002c7d2d78f98fe443c1f9af2b4',
#        'd7c148eb16f56462447f7f9c78ce390d',
#        '402e634d189693e887ccd6e488a4b29d',
#        '41a3987fef185ed06ea962df3493f57a',
#        'd936f8115e8be8a46c5933decd3b6b94',
#        'd754c0b8f318f683355ec2b11954abb4',
#        'c8cef7f9bbed9e8303371f940dcfc495',
#        '41ebb4e4b4434bb495434e6a4026c9d7',
#        '90d8e7b88a0d29d30f98e069b0e2cceb',
#        '87f7997c901c0026e338e6f6d79b385f',
#        '80234017eb6caeada9e14d421eb0b8f8',
#        'edb61d8f85f46f6da703ab9730bf35b1',
#        'f347a8de5e60079db066c440949b8395',
#        'b761841b1bffc40e56e97a869f994f69',
#        '6747991aa8970e35ec44fe90b309d627',
#        'f034b173fe81cebbf8ba0b793c3d3eb1',
#        'd8b297c773294eb23707c0a7f693c5fc',
#        '91b45e8d4bd5c08b849e3a1baea0270a',
#        'b5fa2fc3b3e2a3bbf93884481fb08b74',
#        '0e87195ff59d4294d61b8bffddb3c03c',
#        '5d911ff93f3820e66d76ffe822300426',
#        '8222ee980c821621f5a6cff2b212b2ff',
#        '82c8e033e6fde13b0bf365370407d342',
#        '4d8fb15d5bf045d6fb3809b305ce9d42',
#        'c0440c09698f89df168dc146af067fe7',
#        '4113bf958daeb1b468c147801007dfc3',
#        '5d8aad3fbe2a422089ebf41678bda3ce',
#        '8f6709f15f4f222cf7af5bb49f73aa18',
#        'e18a100e84aefa9da53dc8cc2fd4f22c',
#        '89e6ab133f587191383608ee04cea79a',
#        'a5c7b10a238b041fc8d10afd9cc12569',
#        'f32fbc404c68b727c5bf14bca3ec7b5e',
#        '606147f7461d5d7642f887d6b1b9d16b',
#        '96734f3235d72a018aaef6b78391df7a',
#        'b73e16e580992f545e375c2d3d6f7387',
#        '224ad5cca3b13b0a820052fe0491699a',
#        '58ce2d9435ef94fcf6fe4eeda8387890',
#        'f90442f2620175fa21b6afeda865df11',
#        'b71274108d1bfb8bf7a96b8f512da72b',
#        'acf77cd6d5785f7f95c041f350c9d017',
#        '7729fbb58b8006fe2b8305f9b2b33883',
#        '5fac617f1ce097354f1a28e8fa5036e5',
#        'ede72bdbae3f743b8febe5433c49d126',
#        'f289d19e4b47b6f38bc2dca65d2d40bd',
#        '2dae0b56a64f3708706e63711d970243',
#        'e2f74cb96fb90ec20839f4ff497c007f',
#        'ae9d5b3baccd0f0f32f178b85aa868ff',
#        '78ac03ab2cd9f2e9c7b081761f44f665',
#        '04bb8bd7ee6f88a16623fe5c6dd4da91',
#        'a48b09b94137d7500ba23cfc72c990fa',
#        '74292e695d6b5868b89acf26363ee93e',
#        '330b3939ea1fe042ad347e8d02abc393',
#        '0e6af94d17007c94d858b3bb7adb7dac',
#        'e7a58f5647d24fc877f9cb3d051792e2',
#        '22c9f6b6888cce9bad89c72a2f87e56f',
#        '3c314b1dd87505c653cd66939582a0aa',
#        '74a6dc1a51dffd964baef5089fc4d1b6',
#        '0d3b1464574b7db3d664dc0aa0b66549',
#        '9ef084b09e407e4f8f00932602d1a88d',
#        'd647ae4618fc943d965b25c3aab3fb4c',
#        '8339682fa8a467c49ed7dc1fbaaee361',
#        'd18baf80b9c942af3688e9ddeb3dd18b',
#        '37a64f131e20057e6649e0cf60a3efce',
#        '8d435f703d51586aa164b24e5ec3b9b0',
#        '05dfd35f424da60897dfafc2340e0891',
#        '06f3c1a8441d61da08aac07558ab5f05',
#        '1caa3fd2d741bbb50cc3fdcc32b6f0cd',
#        '038fc325ff4aa0a21c76d5dd7c740c89',
#        '492c436c00725c4c909ec6fbc9223b92',
#        '0c2079e62ddfb06a8a5300cefaa3a970',
#        '45fad4fe08460cf9aec10986ba13c582',
#        'eaa4b09922cfd1c4130787403173e93a',
#        '7f5eab5de5307d4ae8e2a0fa99c0b41a',
#        '16b02dc3b4e8deb6c1cc686c9ef911dd',
#        'c47bf1efb40dc9e8eb8975abcb539ab8',
#        '7df5c81873c74ecc40610a1ad4eb2943',
#        'd07557904cbe57fc1bdebac1e8aeefa1',
#        '8649d84b0796e9deccdd4f6bd8d4e998',
#        'd1713f5cf5838c1592e5f712b5d4928e',
#        'afea04a48a160dbd7418423e6bc4f243',
#        'b32a218326ec600eb1bdc3297eed2c16',
#        '84a27b87601b81cd39889ced2d489f70',
#        'd5f6e4ac57771303fe96ac40b177a28d',
#        '3283c0e38a77249f38ca0c949862726a',
#        '81b8689df47e19fee5d5a2b104a3f8b1',
#        '0e8d3736396b615c0798033f37e4a481',
#        '3033cf4aadc4811b5e714fb3fe295a4e',
#        '04aed38b30c4de9461c8a9940e99d811',
#        'c699f16ba0b86f474390da9515bcad7a',
#        'f58508942604632676c1df2639e18010',
#        'c7d940c13f1be3feeb46adb7e8206de9',
#        '48774729b8921e024731f773e541d248',
#        'c7dfac0ca6b7382d2d51a92ebdf6169e',
#        'c8a24a5d72c93b72685287c27e0d4623',
#        'cd2ca6c232cc1c107ad1249579b457be',
#        '26697f6b3b73c564a0dd92b2fa1a8b0b',
#        'd0ea942db524a895c4bc433e03c3cd3a',
#        'b42e930c16c0166dbeae813b47bb8b07',
#        '93ed73782bc23a0ef9c426c21982d8d7',
#        'fc34c8cc6321cfc97ec35783a5daa937',
#        '071ff9c782ead87dfa9b1c025c25e769',
#        '1bbd7232924e951e7fa87ffa0f62ec3d',
#        'f58ecf974a05d2f5ece85aa9393cf9d6',
#        '7978725e43f1b301551e0fdbc32faef5',
#        'c4d68aad9fdec87b76853d26744026bb'], dtype=object)

# %% [markdown]
# In order to obtain an optimal model to predict the probability of an image belonging to a given class, and baring in mind that there are the following variables to take into consideration:
#
# 1. Number of boxes
# 2. Confidence
#
# Then there is the IOU threshold, but it should be changed as well in the validation images test.
#
# The approach chosen for this is creating a regression model and by maximun likelihood (frequentist approach) obtain the opmital coeficients for both variables. In fact, the idea is to create four different models, compare them, and choose the best from them.
#
# The models are the following, with $BB$ amount of bounding boxes detected in the image, $C_{max}$ the maximum confidence level in the image and p the probability of casifying the image as belonging to the class "Lung opacity":
#
#
# 1. $logit(p)  =  \beta_0 + \beta_1*BB + \beta_2* C_{max} $
# 2. $logit(p)  =  \beta_0 + \beta_1*BB* C_{max} $
# 3. $logit(p)  =  \beta_0 + \beta_1*BB $
# 4. $logit(p)  =  \beta_0 + \beta_2* C_{max} $
